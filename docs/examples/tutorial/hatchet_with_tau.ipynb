# %%
from tau_profile_parser import TauProfileParser
import hatchet as ht

# %% [markdown]
# ### Reading data with the profile parser

# %%
lulesh_data = TauProfileParser.parse('lulesh_profile')

# %% [markdown]
# ### Extracting interval data

# %%
data = lulesh_data.interval_data()

# %% [markdown]
# ### Parsing Call Path data
#
# The callpath data is in the `TAU_CALLPATH` group, so we filter our dataframe to give us only the callpaths.
# Further, the calls in the callpath are joined by ` => `, so we split them into a hierarchical index, and construct a tree from the generated multiindexed dataframe.

# %%
class Node():
    """
    Abstract node of a tree that will be passed to hatchet API
    """
    def __init__(self, name, kwargs):
        raise NotImplemented("Node is abstract")
        
    def to_dict(self):
        """
        Hatchet expects a dictionary representation of each node with at least
        the keys `name`(string) and `metrics`(dict).
        an examplie of metrics would be : {"inclusive_time": 10.0, "exclusive_time": 9.0}
        """
        return {"name": self._name, "metrics": self._metrics}
    
    def _initialize(self, name, kwargs):
        """
        constructor, called by subclasses
        """
        self._name = name
        self._metrics = kwargs
            
class LeafNode(Node):
    """
    Just a node
    """
    def __init__(self, name, **kwargs):
        """
        name: str; name of the timer
        kwargs; metrics of the node
        """
        super(LeafNode, self)._initialize(name, kwargs)
            
class InnerNode(Node):
    """
    A node with children
    """
    def __init__(self, name, **kwargs):
        """
        name: str; name of the timer
        kwargs; metrics of the node
        """
        super(InnerNode, self)._initialize(name, kwargs)
        self._children = set()
        
    def to_dict(self):
        """
        Hatchet expects a inner nodes of the tree to contain, on top of what a regular node contains,
        one extra field called `children`.
        children are also nodes.
        """
        children = []
        for child in self._children:
            children.append(child.to_dict())
        return {"name": self._name, "metrics": self._metrics, "children": children}
    
    def add_children(self, node):
        self._children.add(node)
        

class CallPaths():
    """
    Generates call paths that are understood by hatchet
    """
    def __init__(self, non_call_path_data, call_path_data):
        """ initializer should not be directly called instead use factory method """
        self._roots = []
        self._non_call_path = non_call_path_data
        self._call_path_data = call_path_data
        self._depth = len(call_path.index.levshape)
        self._recursive_constructor(self._call_path_data, None, 0)
        
    def get_roots(self):
        """
        creates a json-like (list of dictionaries) that is understood by hatchet.GraphFrame.from_literal() method.
        """
        return [root.to_dict() for root in self._roots]

    def _recursive_constructor(self, call_path_data, parent_node, level):
        """recursively builds the tree"""
        functions_on_this_level = list(call_path_data.groupby(level=0).groups.keys())
        functions_on_this_level = [i.strip() for i in functions_on_this_level]
        for func in functions_on_this_level:
            if level == self._depth - 1 or func == 'NaN':
                node = LeafNode(func, exclusive_time=self._non_call_path.loc[func]['Exclusive'],
                                      inclusive_time=self._non_call_path.loc[func]['Inclusive'])
            else:
                node = InnerNode(func, exclusive_time=self._non_call_path.loc[func]['Exclusive'],
                                      inclusive_time=self._non_call_path.loc[func]['Inclusive'])
                self._recursive_constructor(call_path_data.loc[func], node, level + 1)

            if parent_node is not None:
                parent_node.add_children(node)
            else:
                self._roots.append(node)
                
    @staticmethod
    def _get_call_paths(data, node, context, thread):
        data = data[data['Group'].str.contains('TAU_CALLPATH', regex=False)].loc[node, context, thread]
        data = data.set_index(data.index.str.split("\s*=>\s*", expand=True))
        return data
        
    @staticmethod
    def _get_non_call_paths(data, node, context, thread):
        data = data[~data['Group'].str.contains('TAU_CALLPATH', regex=False)].loc[node, context, thread]
        data = data.set_index(data.index.str.strip())
        return data

    @staticmethod
    def from_tau_interval_profile(tau_interval, node, context, thread):
        """
        Creates and returns a CallPath object
        
        tau_interval: pandas.DataFrame; the interval data from TauProfileParser
        node: int
        contex: int
        thread: int
        """
        non_call_path_data = CallPaths._get_non_call_paths(tau_interval, node, context, thread)
        call_path_data = CallPaths._get_call_paths(tau_interval, node, context, thread)
        return CallPaths(non_call_path_data, call_path_data)

# %%
call_paths = CallPaths.from_tau_interval_profile(data, 0, 0, 0)

# %%
graph_dict = call_paths.get_roots()

# %%
gf = ht.GraphFrame.from_literal(graph_dict)

# %%
print(gf.tree(color=True, metric_column="exclusive_time"))
# Out:
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.2.0
#
# 1396259.000 .TAU application
# └─ 0.000 [CONTEXT] .TAU application
#    ├─ 8003.000 [SAMPLE] CalcElemV...lulesh.cc} {1341}]
#    ├─ 2000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2075}]
#    ├─ 1005.000 [SAMPLE] CalcMonot...lulesh.cc} {1936}]
#    ├─ 4000.000 [SAMPLE] CalcPress...lulesh.cc} {2022}]
#    ├─ 18000.000 [SAMPLE] CalcPress...lulesh.cc} {2029}]
#    ├─ 851.000 [SAMPLE] CalcQForE...lulesh.cc} {1995}]
#    ├─ 22851.000 [SAMPLE] CalcQForE...lulesh.cc} {1996}]
#    ├─ 1001.000 [SAMPLE] Domain::D...sh-init.cc} {174}]
#    ├─ 1001.000 [SAMPLE] Domain::S...sh-init.cc} {291}]
#    ├─ 1002.000 [SAMPLE] Domain::S...sh-init.cc} {316}]
#    ├─ 1000.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2238}]
#    ├─ 999.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2289}]
#    ├─ 18000.000 [SAMPLE] Tau_memor...Memory.cpp} {957}]
#    ├─ 3994.000 [SAMPLE] _IO_vfprintf_internal [{} {0}]
#    ├─ 998.000 [SAMPLE] __GI__IO_sputbackc [{} {0}]
#    ├─ 1365.000 [SAMPLE] __GI___fork [{} {0}]
#    ├─ 12959.000 [SAMPLE] __GI___libc_free [{} {0}]
#    ├─ 63612.000 [SAMPLE] __GI___libc_malloc [{} {0}]
#    ├─ 1999.000 [SAMPLE] __GI___mempcpy [{} {0}]
#    ├─ 4000.000 [SAMPLE] __GI___printf_fp_l [{} {0}]
#    ├─ 1000.000 [SAMPLE] __GI_getenv [{} {0}]
#    ├─ 317313.000 [SAMPLE] __brk [{} {0}]
#    ├─ 5999.000 [SAMPLE] __gnu_cxx...algobase.h} {754}]
#    ├─ 998.000 [SAMPLE] __gnu_cxx...algobase.h} {754}]
#    ├─ 1004.000 [SAMPLE] __ioctl [{} {0}]
#    ├─ 101647.000 [SAMPLE] __kmp_GOM...gsupport.cpp} {0}]
#    ├─ 37999.000 [SAMPLE] __kmp_api..._parallel [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 28861.000 [SAMPLE] __kmp_get...thread_id [{} {0}]
#    ├─ 26905.000 [SAMPLE] __kmp_get...ad_id_reg [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 3999.000 [SAMPLE] __kmpc_ok.../libiomp5.so} {0}]
#    ├─ 1008.000 [SAMPLE] __libc_recv [{} {0}]
#    ├─ 3053.000 [SAMPLE] __munmap [{} {0}]
#    ├─ 1002.000 [SAMPLE] __nanosleep_nocancel [{} {0}]
#    ├─ 42750.000 [SAMPLE] __ompt_ge...**, int*) [{} {0}]
#    ├─ 35914.000 [SAMPLE] __ompt_ge...ject(int) [{} {0}]
#    ├─ 1003.000 [SAMPLE] __open [{} {0}]
#    ├─ 39042.000 [SAMPLE] __pthread_cond_wait [{} {0}]
#    ├─ 997.000 [SAMPLE] __random [{} {0}]
#    ├─ 1996.000 [SAMPLE] __read [{} {0}]
#    ├─ 205056.000 [SAMPLE] __read_nocancel [{} {0}]
#    ├─ 1000.000 [SAMPLE] __strchrnul [{} {0}]
#    ├─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
#    ├─ 26078.000 [SAMPLE] __write_nocancel [{} {0}]
#    ├─ 988.000 [SAMPLE] _dl_check_caller [{} {0}]
#    ├─ 996.000 [SAMPLE] _dl_name_match_p [{} {0}]
#    ├─ 66059.000 [SAMPLE] _int_free [{malloc.c} {0}]
#    ├─ 32725.000 [SAMPLE] _int_malloc [{malloc.c} {0}]
#    ├─ 1007.000 [SAMPLE] _xstat [{} {0}]
#    ├─ 2994.000 [SAMPLE] check_mat...{dl-lookup.c} {0}]
#    ├─ 19950.000 [SAMPLE] do_lookup...{dl-lookup.c} {0}]
#    ├─ 1000.000 [SAMPLE] group_reg..._var_group.c} {0}]
#    ├─ 26004.000 [SAMPLE] malloc_co...e [{malloc.c} {0}]
#    ├─ 1001.000 [SAMPLE] mca_base_...al.so.40.0.0} {0}]
#    ├─ 994.000 [SAMPLE] memset [{} {0}]
#    ├─ 1004.000 [SAMPLE] munmap [{} {0}]
#    ├─ 1001.000 [SAMPLE] ompi_data...pi.so.40.0.0} {0}]
#    ├─ 3999.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {179}]
#    ├─ 1002.000 [SAMPLE] std::char...r_traits.h} {350}]
#    ├─ 7000.000 [SAMPLE] std::ctyp...e_facets.h} {901}]
#    ├─ 1999.000 [SAMPLE] strcmp [{} {0}]
#    └─ 30020.000 [SAMPLE] sysmalloc [{malloc.c} {0}]
# 7493651.000 OpenMP_Implicit_Task
# └─ 0.000 [CONTEXT] OpenMP_Implicit_Task
#    ├─ 2635.000 [SAMPLE] ApplyMate...lulesh.cc} {2343}]
#    ├─ 2849.000 [SAMPLE] ApplyMate...lulesh.cc} {2350}]
#    ├─ 1835.000 [SAMPLE] ApplyMate...lulesh.cc} {2351}]
#    ├─ 930.000 [SAMPLE] ApplyMate...lulesh.cc} {2359}]
#    ├─ 1841.000 [SAMPLE] ApplyMate...lulesh.cc} {2369}]
#    ├─ 1871.000 [SAMPLE] ApplyMate...lulesh.cc} {2375}]
#    ├─ 4002.000 [SAMPLE] AreaFace ...lulesh.cc} {1378}]
#    ├─ 12009.000 [SAMPLE] AreaFace ...lulesh.cc} {1379}]
#    ├─ 9006.000 [SAMPLE] AreaFace ...lulesh.cc} {1380}]
#    ├─ 3002.000 [SAMPLE] AreaFace ...lulesh.cc} {1383}]
#    ├─ 2000.000 [SAMPLE] AreaFace ...lulesh.cc} {1384}]
#    ├─ 2997.000 [SAMPLE] AreaFace ...lulesh.cc} {1385}]
#    ├─ 3002.000 [SAMPLE] AreaFace ...lulesh.cc} {1386}]
#    ├─ 15013.000 [SAMPLE] AreaFace ...lulesh.cc} {1387}]
#    ├─ 2017.000 [SAMPLE] CalcAccel...lulesh.cc} {1145}]
#    ├─ 3998.000 [SAMPLE] CalcAccel...lulesh.cc} {1146}]
#    ├─ 4000.000 [SAMPLE] CalcAccel...lulesh.cc} {1147}]
#    ├─ 999.000 [SAMPLE] CalcCoura...lulesh.cc} {2462}]
#    ├─ 4000.000 [SAMPLE] CalcCoura...lulesh.cc} {2479}]
#    ├─ 6000.000 [SAMPLE] CalcCoura...lulesh.cc} {2486}]
#    ├─ 1000.000 [SAMPLE] CalcCoura...lulesh.cc} {2488}]
#    ├─ 7005.000 [SAMPLE] CalcElemC...lulesh.cc} {1432}]
#    ├─ 10999.000 [SAMPLE] CalcElemF.../lulesh.cc} {674}]
#    ├─ 5997.000 [SAMPLE] CalcElemF.../lulesh.cc} {675}]
#    ├─ 7999.000 [SAMPLE] CalcElemF.../lulesh.cc} {676}]
#    ├─ 6000.000 [SAMPLE] CalcElemF.../lulesh.cc} {677}]
#    ├─ 8999.000 [SAMPLE] CalcElemF.../lulesh.cc} {679}]
#    ├─ 29987.000 [SAMPLE] CalcElemF.../lulesh.cc} {680}]
#    ├─ 26999.000 [SAMPLE] CalcElemF.../lulesh.cc} {681}]
#    ├─ 13998.000 [SAMPLE] CalcElemF.../lulesh.cc} {682}]
#    ├─ 1998.000 [SAMPLE] CalcElemF.../lulesh.cc} {684}]
#    ├─ 4998.000 [SAMPLE] CalcElemF.../lulesh.cc} {685}]
#    ├─ 12000.000 [SAMPLE] CalcElemF.../lulesh.cc} {686}]
#    ├─ 4000.000 [SAMPLE] CalcElemF.../lulesh.cc} {688}]
#    ├─ 10998.000 [SAMPLE] CalcElemF.../lulesh.cc} {690}]
#    ├─ 14000.000 [SAMPLE] CalcElemF.../lulesh.cc} {691}]
#    ├─ 16994.000 [SAMPLE] CalcElemF.../lulesh.cc} {692}]
#    ├─ 24996.000 [SAMPLE] CalcElemF.../lulesh.cc} {693}]
#    ├─ 999.000 [SAMPLE] CalcElemF.../lulesh.cc} {695}]
#    ├─ 3001.000 [SAMPLE] CalcElemF.../lulesh.cc} {696}]
#    ├─ 7999.000 [SAMPLE] CalcElemF.../lulesh.cc} {697}]
#    ├─ 1000.000 [SAMPLE] CalcElemF.../lulesh.cc} {698}]
#    ├─ 8996.000 [SAMPLE] CalcElemF.../lulesh.cc} {699}]
#    ├─ 999.000 [SAMPLE] CalcElemF.../lulesh.cc} {701}]
#    ├─ 14983.000 [SAMPLE] CalcElemF.../lulesh.cc} {702}]
#    ├─ 13996.000 [SAMPLE] CalcElemF.../lulesh.cc} {703}]
#    ├─ 2997.000 [SAMPLE] CalcElemF.../lulesh.cc} {704}]
#    ├─ 8006.000 [SAMPLE] CalcElemN.../lulesh.cc} {427}]
#    ├─ 17006.000 [SAMPLE] CalcElemN.../lulesh.cc} {428}]
#    ├─ 13001.000 [SAMPLE] CalcElemN.../lulesh.cc} {430}]
#    ├─ 8005.000 [SAMPLE] CalcElemS.../lulesh.cc} {319}]
#    ├─ 8003.000 [SAMPLE] CalcElemS.../lulesh.cc} {320}]
#    ├─ 6006.000 [SAMPLE] CalcElemS.../lulesh.cc} {323}]
#    ├─ 2002.000 [SAMPLE] CalcElemS.../lulesh.cc} {324}]
#    ├─ 8002.000 [SAMPLE] CalcElemS.../lulesh.cc} {325}]
#    ├─ 16012.000 [SAMPLE] CalcElemS.../lulesh.cc} {327}]
#    ├─ 20007.000 [SAMPLE] CalcElemS.../lulesh.cc} {329}]
#    ├─ 2001.000 [SAMPLE] CalcElemS.../lulesh.cc} {332}]
#    ├─ 9001.000 [SAMPLE] CalcElemS.../lulesh.cc} {333}]
#    ├─ 6004.000 [SAMPLE] CalcElemS.../lulesh.cc} {334}]
#    ├─ 5003.000 [SAMPLE] CalcElemS.../lulesh.cc} {336}]
#    ├─ 7002.000 [SAMPLE] CalcElemS.../lulesh.cc} {337}]
#    ├─ 3002.000 [SAMPLE] CalcElemS.../lulesh.cc} {338}]
#    ├─ 2002.000 [SAMPLE] CalcElemS.../lulesh.cc} {340}]
#    ├─ 3002.000 [SAMPLE] CalcElemS.../lulesh.cc} {342}]
#    ├─ 6002.000 [SAMPLE] CalcElemS.../lulesh.cc} {348}]
#    ├─ 20004.000 [SAMPLE] CalcElemS.../lulesh.cc} {350}]
#    ├─ 2001.000 [SAMPLE] CalcElemS.../lulesh.cc} {351}]
#    ├─ 1001.000 [SAMPLE] CalcElemS.../lulesh.cc} {354}]
#    ├─ 1001.000 [SAMPLE] CalcElemS.../lulesh.cc} {355}]
#    ├─ 2002.000 [SAMPLE] CalcElemS.../lulesh.cc} {357}]
#    ├─ 8001.000 [SAMPLE] CalcElemS.../lulesh.cc} {359}]
#    ├─ 1001.000 [SAMPLE] CalcElemS.../lulesh.cc} {360}]
#    ├─ 15007.000 [SAMPLE] CalcElemS.../lulesh.cc} {363}]
#    ├─ 2003.000 [SAMPLE] CalcElemS.../lulesh.cc} {366}]
#    ├─ 9002.000 [SAMPLE] CalcElemS.../lulesh.cc} {367}]
#    ├─ 1001.000 [SAMPLE] CalcElemS.../lulesh.cc} {368}]
#    ├─ 2001.000 [SAMPLE] CalcElemS.../lulesh.cc} {370}]
#    ├─ 1001.000 [SAMPLE] CalcElemS.../lulesh.cc} {371}]
#    ├─ 2002.000 [SAMPLE] CalcElemS.../lulesh.cc} {373}]
#    ├─ 3002.000 [SAMPLE] CalcElemS.../lulesh.cc} {376}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1447}]
#    ├─ 2001.000 [SAMPLE] CalcElemV...lulesh.cc} {1453}]
#    ├─ 7006.000 [SAMPLE] CalcElemV...lulesh.cc} {1458}]
#    ├─ 1000.000 [SAMPLE] CalcElemV...lulesh.cc} {1464}]
#    ├─ 1002.000 [SAMPLE] CalcElemV...lulesh.cc} {1465}]
#    ├─ 999.000 [SAMPLE] CalcElemV...lulesh.cc} {1291}]
#    ├─ 3002.000 [SAMPLE] CalcElemV...lulesh.cc} {1295}]
#    ├─ 2002.000 [SAMPLE] CalcElemV...lulesh.cc} {1297}]
#    ├─ 3004.000 [SAMPLE] CalcElemV...lulesh.cc} {1298}]
#    ├─ 2002.000 [SAMPLE] CalcElemV...lulesh.cc} {1301}]
#    ├─ 1000.000 [SAMPLE] CalcElemV...lulesh.cc} {1311}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1313}]
#    ├─ 998.000 [SAMPLE] CalcElemV...lulesh.cc} {1315}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1322}]
#    ├─ 3002.000 [SAMPLE] CalcElemV...lulesh.cc} {1323}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1326}]
#    ├─ 2002.000 [SAMPLE] CalcElemV...lulesh.cc} {1329}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1330}]
#    ├─ 3004.000 [SAMPLE] CalcElemV...lulesh.cc} {1333}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1334}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1335}]
#    ├─ 8003.000 [SAMPLE] CalcElemV...lulesh.cc} {1341}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1347}]
#    ├─ 2001.000 [SAMPLE] CalcElemV...lulesh.cc} {1353}]
#    ├─ 2001.000 [SAMPLE] CalcElemV...lulesh.cc} {1362}]
#    ├─ 2000.000 [SAMPLE] CalcElemV...lulesh.cc} {1363}]
#    ├─ 1997.000 [SAMPLE] CalcElemV...lulesh.cc} {1366}]
#    ├─ 38996.000 [SAMPLE] CalcEnerg...lulesh.cc} {2064}]
#    ├─ 20998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2065}]
#    ├─ 53995.000 [SAMPLE] CalcEnerg...lulesh.cc} {2068}]
#    ├─ 10999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2075}]
#    ├─ 6000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2077}]
#    ├─ 19998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2079}]
#    ├─ 26997.000 [SAMPLE] CalcEnerg...lulesh.cc} {2083}]
#    ├─ 28797.000 [SAMPLE] CalcEnerg...lulesh.cc} {2084}]
#    ├─ 40000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2086}]
#    ├─ 11000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2087}]
#    ├─ 44910.000 [SAMPLE] CalcEnerg...lulesh.cc} {2092}]
#    ├─ 34992.000 [SAMPLE] CalcEnerg...lulesh.cc} {2095}]
#    ├─ 39999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2096}]
#    ├─ 12999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2097}]
#    ├─ 1000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2100}]
#    ├─ 32995.000 [SAMPLE] CalcEnerg...lulesh.cc} {2103}]
#    ├─ 4998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2105}]
#    ├─ 5000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2106}]
#    ├─ 21000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2109}]
#    ├─ 9999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2116}]
#    ├─ 64987.000 [SAMPLE] CalcEnerg...lulesh.cc} {2122}]
#    ├─ 10008.000 [SAMPLE] CalcEnerg...lulesh.cc} {2123}]
#    ├─ 18999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2126}]
#    ├─ 19000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2127}]
#    ├─ 15998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2129}]
#    ├─ 14000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2135}]
#    ├─ 22766.000 [SAMPLE] CalcEnerg...lulesh.cc} {2138}]
#    ├─ 32998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2139}]
#    ├─ 12998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2140}]
#    ├─ 15989.000 [SAMPLE] CalcEnerg...lulesh.cc} {2143}]
#    ├─ 52992.000 [SAMPLE] CalcEnerg...lulesh.cc} {2146}]
#    ├─ 1999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2153}]
#    ├─ 17015.000 [SAMPLE] CalcEnerg...lulesh.cc} {2157}]
#    ├─ 7000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2158}]
#    ├─ 26997.000 [SAMPLE] CalcEnerg...lulesh.cc} {2159}]
#    ├─ 48998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2161}]
#    ├─ 4000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2162}]
#    ├─ 7999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2167}]
#    ├─ 12999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2169}]
#    ├─ 2001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {782}]
#    ├─ 3999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {794}]
#    ├─ 8000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {799}]
#    ├─ 11000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {800}]
#    ├─ 3996.000 [SAMPLE] CalcFBHou.../lulesh.cc} {801}]
#    ├─ 22994.000 [SAMPLE] CalcFBHou.../lulesh.cc} {802}]
#    ├─ 3997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {805}]
#    ├─ 1998.000 [SAMPLE] CalcFBHou.../lulesh.cc} {806}]
#    ├─ 1000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {807}]
#    ├─ 21988.000 [SAMPLE] CalcFBHou.../lulesh.cc} {808}]
#    ├─ 8000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {810}]
#    ├─ 7983.000 [SAMPLE] CalcFBHou.../lulesh.cc} {811}]
#    ├─ 12996.000 [SAMPLE] CalcFBHou.../lulesh.cc} {812}]
#    ├─ 4000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {813}]
#    ├─ 13996.000 [SAMPLE] CalcFBHou.../lulesh.cc} {814}]
#    ├─ 17992.000 [SAMPLE] CalcFBHou.../lulesh.cc} {816}]
#    ├─ 21001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {817}]
#    ├─ 6999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {818}]
#    ├─ 36995.000 [SAMPLE] CalcFBHou.../lulesh.cc} {820}]
#    ├─ 28000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {821}]
#    ├─ 4997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {822}]
#    ├─ 3000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {824}]
#    ├─ 16997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {825}]
#    ├─ 13995.000 [SAMPLE] CalcFBHou.../lulesh.cc} {828}]
#    ├─ 4997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {829}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {830}]
#    ├─ 2997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {832}]
#    ├─ 2001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {833}]
#    ├─ 6997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {834}]
#    ├─ 3997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {836}]
#    ├─ 6993.000 [SAMPLE] CalcFBHou.../lulesh.cc} {838}]
#    ├─ 15999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {840}]
#    ├─ 3997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {841}]
#    ├─ 3000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {842}]
#    ├─ 2000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {844}]
#    ├─ 1000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {845}]
#    ├─ 9000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {846}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {854}]
#    ├─ 3000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {873}]
#    ├─ 7000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {876}]
#    ├─ 1998.000 [SAMPLE] CalcFBHou.../lulesh.cc} {879}]
#    ├─ 1001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {888}]
#    ├─ 998.000 [SAMPLE] CalcFBHou.../lulesh.cc} {889}]
#    ├─ 1998.000 [SAMPLE] CalcFBHou.../lulesh.cc} {890}]
#    ├─ 6992.000 [SAMPLE] CalcFBHou.../lulesh.cc} {893}]
#    ├─ 1000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {903}]
#    ├─ 1000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {904}]
#    ├─ 2001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {908}]
#    ├─ 3001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {915}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {916}]
#    ├─ 1000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {917}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {924}]
#    ├─ 7000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {926}]
#    ├─ 1999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {928}]
#    ├─ 5999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {929}]
#    ├─ 89049.000 [SAMPLE] CalcFBHou.../lulesh.cc} {930}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {974}]
#    ├─ 14001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {977}]
#    ├─ 3998.000 [SAMPLE] CalcFBHou.../lulesh.cc} {979}]
#    ├─ 11002.000 [SAMPLE] CalcFBHou.../lulesh.cc} {980}]
#    ├─ 12999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {981}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {984}]
#    ├─ 4999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {985}]
#    ├─ 9016.000 [SAMPLE] CalcForce...lulesh.cc} {1116}]
#    ├─ 15029.000 [SAMPLE] CalcForce...lulesh.cc} {1117}]
#    ├─ 7008.000 [SAMPLE] CalcForce...lulesh.cc} {1118}]
#    ├─ 6002.000 [SAMPLE] CalcHourg...lulesh.cc} {1023}]
#    ├─ 8951.000 [SAMPLE] CalcHourg...lulesh.cc} {1025}]
#    ├─ 15008.000 [SAMPLE] CalcHourg...lulesh.cc} {1026}]
#    ├─ 6003.000 [SAMPLE] CalcHourg...lulesh.cc} {1027}]
#    ├─ 39042.000 [SAMPLE] CalcHourg...lulesh.cc} {1028}]
#    ├─ 14005.000 [SAMPLE] CalcHourg...lulesh.cc} {1031}]
#    ├─ 15003.000 [SAMPLE] CalcHourg...lulesh.cc} {1034}]
#    ├─ 1000.000 [SAMPLE] CalcHydro...lulesh.cc} {2544}]
#    ├─ 2981.000 [SAMPLE] CalcHydro...lulesh.cc} {2546}]
#    ├─ 2000.000 [SAMPLE] CalcHydro...lulesh.cc} {2547}]
#    ├─ 4000.000 [SAMPLE] CalcHydro...lulesh.cc} {2550}]
#    ├─ 1001.000 [SAMPLE] CalcKinem...lulesh.cc} {1531}]
#    ├─ 2001.000 [SAMPLE] CalcKinem...lulesh.cc} {1532}]
#    ├─ 4001.000 [SAMPLE] CalcKinem...lulesh.cc} {1533}]
#    ├─ 2001.000 [SAMPLE] CalcKinem...lulesh.cc} {1534}]
#    ├─ 3002.000 [SAMPLE] CalcKinem...lulesh.cc} {1537}]
#    ├─ 2002.000 [SAMPLE] CalcKinem...lulesh.cc} {1541}]
#    ├─ 2000.000 [SAMPLE] CalcKinem...lulesh.cc} {1544}]
#    ├─ 2002.000 [SAMPLE] CalcKinem...lulesh.cc} {1545}]
#    ├─ 3002.000 [SAMPLE] CalcKinem...lulesh.cc} {1546}]
#    ├─ 1001.000 [SAMPLE] CalcKinem...lulesh.cc} {1550}]
#    ├─ 3001.000 [SAMPLE] CalcKinem...lulesh.cc} {1552}]
#    ├─ 4002.000 [SAMPLE] CalcKinem...lulesh.cc} {1553}]
#    ├─ 5005.000 [SAMPLE] CalcKinem...lulesh.cc} {1554}]
#    ├─ 2001.000 [SAMPLE] CalcKinem...lulesh.cc} {1564}]
#    ├─ 2001.000 [SAMPLE] CalcLagra...lulesh.cc} {1588}]
#    ├─ 7007.000 [SAMPLE] CalcLagra...lulesh.cc} {1593}]
#    ├─ 1000.000 [SAMPLE] CalcLagra...lulesh.cc} {1594}]
#    ├─ 8006.000 [SAMPLE] CalcLagra...lulesh.cc} {1595}]
#    ├─ 2002.000 [SAMPLE] CalcLagra...lulesh.cc} {1598}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1644}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1646}]
#    ├─ 1000.000 [SAMPLE] CalcMonot...lulesh.cc} {1650}]
#    ├─ 999.000 [SAMPLE] CalcMonot...lulesh.cc} {1661}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1670}]
#    ├─ 3001.000 [SAMPLE] CalcMonot...lulesh.cc} {1672}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1676}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1680}]
#    ├─ 2001.000 [SAMPLE] CalcMonot...lulesh.cc} {1686}]
#    ├─ 4003.000 [SAMPLE] CalcMonot...lulesh.cc} {1688}]
#    ├─ 5005.000 [SAMPLE] CalcMonot...lulesh.cc} {1691}]
#    ├─ 5796.000 [SAMPLE] CalcMonot...lulesh.cc} {1692}]
#    ├─ 3002.000 [SAMPLE] CalcMonot...lulesh.cc} {1693}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1696}]
#    ├─ 3003.000 [SAMPLE] CalcMonot...lulesh.cc} {1697}]
#    ├─ 3003.000 [SAMPLE] CalcMonot...lulesh.cc} {1699}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1700}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1701}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1706}]
#    ├─ 11008.000 [SAMPLE] CalcMonot...lulesh.cc} {1709}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1711}]
#    ├─ 13019.000 [SAMPLE] CalcMonot...lulesh.cc} {1715}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1716}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1717}]
#    ├─ 1000.000 [SAMPLE] CalcMonot...lulesh.cc} {1723}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1727}]
#    ├─ 4004.000 [SAMPLE] CalcMonot...lulesh.cc} {1733}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1734}]
#    ├─ 3885.000 [SAMPLE] CalcMonot...lulesh.cc} {1735}]
#    ├─ 5004.000 [SAMPLE] CalcMonot...lulesh.cc} {1737}]
#    ├─ 1000.000 [SAMPLE] CalcMonot...lulesh.cc} {1743}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1745}]
#    ├─ 2001.000 [SAMPLE] CalcMonot...lulesh.cc} {1747}]
#    ├─ 1768.000 [SAMPLE] CalcMonot...lulesh.cc} {1749}]
#    ├─ 8009.000 [SAMPLE] CalcMonot...lulesh.cc} {1751}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1753}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1755}]
#    ├─ 1629.000 [SAMPLE] CalcMonot...lulesh.cc} {1772}]
#    ├─ 3002.000 [SAMPLE] CalcMonot...lulesh.cc} {1775}]
#    ├─ 1907.000 [SAMPLE] CalcMonot...lulesh.cc} {1781}]
#    ├─ 2814.000 [SAMPLE] CalcMonot...lulesh.cc} {1793}]
#    ├─ 1000.000 [SAMPLE] CalcMonot...lulesh.cc} {1805}]
#    ├─ 1770.000 [SAMPLE] CalcMonot...lulesh.cc} {1811}]
#    ├─ 1841.000 [SAMPLE] CalcMonot...lulesh.cc} {1812}]
#    ├─ 2826.000 [SAMPLE] CalcMonot...lulesh.cc} {1813}]
#    ├─ 3616.000 [SAMPLE] CalcMonot...lulesh.cc} {1817}]
#    ├─ 816.000 [SAMPLE] CalcMonot...lulesh.cc} {1819}]
#    ├─ 6832.000 [SAMPLE] CalcMonot...lulesh.cc} {1829}]
#    ├─ 1910.000 [SAMPLE] CalcMonot...lulesh.cc} {1831}]
#    ├─ 902.000 [SAMPLE] CalcMonot...lulesh.cc} {1843}]
#    ├─ 1807.000 [SAMPLE] CalcMonot...lulesh.cc} {1850}]
#    ├─ 1789.000 [SAMPLE] CalcMonot...lulesh.cc} {1851}]
#    ├─ 798.000 [SAMPLE] CalcMonot...lulesh.cc} {1854}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1866}]
#    ├─ 5181.000 [SAMPLE] CalcMonot...lulesh.cc} {1868}]
#    ├─ 1944.000 [SAMPLE] CalcMonot...lulesh.cc} {1882}]
#    ├─ 841.000 [SAMPLE] CalcMonot...lulesh.cc} {1894}]
#    ├─ 1831.000 [SAMPLE] CalcMonot...lulesh.cc} {1897}]
#    ├─ 2588.000 [SAMPLE] CalcMonot...lulesh.cc} {1898}]
#    ├─ 1794.000 [SAMPLE] CalcMonot...lulesh.cc} {1899}]
#    ├─ 4841.000 [SAMPLE] CalcMonot...lulesh.cc} {1901}]
#    ├─ 1000.000 [SAMPLE] CalcMonot...lulesh.cc} {1907}]
#    ├─ 848.000 [SAMPLE] CalcMonot...lulesh.cc} {1908}]
#    ├─ 831.000 [SAMPLE] CalcMonot...lulesh.cc} {1912}]
#    ├─ 784.000 [SAMPLE] CalcMonot...lulesh.cc} {1914}]
#    ├─ 2615.000 [SAMPLE] CalcMonot...lulesh.cc} {1918}]
#    ├─ 2001.000 [SAMPLE] CalcPosit...lulesh.cc} {1215}]
#    ├─ 2002.000 [SAMPLE] CalcPosit...lulesh.cc} {1216}]
#    ├─ 3003.000 [SAMPLE] CalcPosit...lulesh.cc} {1217}]
#    ├─ 8999.000 [SAMPLE] CalcPress...lulesh.cc} {2022}]
#    ├─ 351733.000 [SAMPLE] CalcPress...lulesh.cc} {2025}]
#    ├─ 208637.000 [SAMPLE] CalcPress...lulesh.cc} {2026}]
#    ├─ 9999.000 [SAMPLE] CalcPress...lulesh.cc} {2029}]
#    ├─ 18967.000 [SAMPLE] CalcPress...lulesh.cc} {2031}]
#    ├─ 12010.000 [SAMPLE] CalcPress...lulesh.cc} {2033}]
#    ├─ 31995.000 [SAMPLE] CalcPress...lulesh.cc} {2035}]
#    ├─ 19000.000 [SAMPLE] CalcPress...lulesh.cc} {2036}]
#    ├─ 32999.000 [SAMPLE] CalcPress...lulesh.cc} {2038}]
#    ├─ 61821.000 [SAMPLE] CalcPress...lulesh.cc} {2042}]
#    ├─ 1000.000 [SAMPLE] CalcSound...lulesh.cc} {2187}]
#    ├─ 6998.000 [SAMPLE] CalcSound...lulesh.cc} {2190}]
#    ├─ 4999.000 [SAMPLE] CalcSound...lulesh.cc} {2191}]
#    ├─ 3000.000 [SAMPLE] CalcSound...lulesh.cc} {2192}]
#    ├─ 3002.000 [SAMPLE] CalcVeloc...lulesh.cc} {1194}]
#    ├─ 1001.000 [SAMPLE] CalcVeloc...lulesh.cc} {1195}]
#    ├─ 1001.000 [SAMPLE] CalcVeloc...lulesh.cc} {1199}]
#    ├─ 2002.000 [SAMPLE] CalcVeloc...lulesh.cc} {1202}]
#    ├─ 1001.000 [SAMPLE] CalcVeloc...lulesh.cc} {1203}]
#    ├─ 3000.000 [SAMPLE] CalcVolum...lulesh.cc} {1084}]
#    ├─ 4001.000 [SAMPLE] CollectDo.../lulesh.cc} {238}]
#    ├─ 8001.000 [SAMPLE] CollectDo.../lulesh.cc} {242}]
#    ├─ 7003.000 [SAMPLE] CollectDo.../lulesh.cc} {243}]
#    ├─ 20004.000 [SAMPLE] CollectDo.../lulesh.cc} {244}]
#    ├─ 23006.000 [SAMPLE] CollectDo.../lulesh.cc} {245}]
#    ├─ 6003.000 [SAMPLE] CollectDo.../lulesh.cc} {246}]
#    ├─ 3013.000 [SAMPLE] CollectDo.../lulesh.cc} {247}]
#    ├─ 4003.000 [SAMPLE] CollectDo.../lulesh.cc} {248}]
#    ├─ 9003.000 [SAMPLE] CollectDo.../lulesh.cc} {249}]
#    ├─ 13006.000 [SAMPLE] CollectDo.../lulesh.cc} {251}]
#    ├─ 5001.000 [SAMPLE] CollectDo.../lulesh.cc} {252}]
#    ├─ 41028.000 [SAMPLE] CollectDo.../lulesh.cc} {253}]
#    ├─ 13018.000 [SAMPLE] CollectDo.../lulesh.cc} {254}]
#    ├─ 1001.000 [SAMPLE] CollectDo.../lulesh.cc} {255}]
#    ├─ 24012.000 [SAMPLE] CollectDo.../lulesh.cc} {256}]
#    ├─ 2002.000 [SAMPLE] CollectDo.../lulesh.cc} {257}]
#    ├─ 9017.000 [SAMPLE] CollectDo.../lulesh.cc} {258}]
#    ├─ 26006.000 [SAMPLE] CollectDo.../lulesh.cc} {260}]
#    ├─ 44014.000 [SAMPLE] CollectDo.../lulesh.cc} {261}]
#    ├─ 4004.000 [SAMPLE] CollectDo.../lulesh.cc} {262}]
#    ├─ 1001.000 [SAMPLE] CollectDo.../lulesh.cc} {263}]
#    ├─ 17012.000 [SAMPLE] CollectDo.../lulesh.cc} {265}]
#    ├─ 23010.000 [SAMPLE] CollectDo.../lulesh.cc} {266}]
#    ├─ 20004.000 [SAMPLE] CollectDo.../lulesh.cc} {267}]
#    ├─ 12001.000 [SAMPLE] Domain::e...H/lulesh.h} {336}]
#    ├─ 2001.000 [SAMPLE] Domain::n...H/lulesh.h} {372}]
#    ├─ 2001.000 [SAMPLE] Domain::n...H/lulesh.h} {369}]
#    ├─ 11006.000 [SAMPLE] Domain::x...H/lulesh.h} {265}]
#    ├─ 2998.000 [SAMPLE] Domain::x...H/lulesh.h} {270}]
#    ├─ 2999.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2240}]
#    ├─ 156572.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2245}]
#    ├─ 18790.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2246}]
#    ├─ 148004.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2247}]
#    ├─ 48746.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2248}]
#    ├─ 196939.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2249}]
#    ├─ 105757.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2250}]
#    ├─ 129795.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2257}]
#    ├─ 42878.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2258}]
#    ├─ 97847.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2259}]
#    ├─ 18007.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2267}]
#    ├─ 6999.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2268}]
#    ├─ 17997.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2276}]
#    ├─ 49964.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2286}]
#    ├─ 10001.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2300}]
#    ├─ 9998.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2301}]
#    ├─ 21998.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2302}]
#    ├─ 64991.000 [SAMPLE] FABS(doub...SH/lulesh.h} {52}]
#    ├─ 21009.000 [SAMPLE] InitStres.../lulesh.cc} {284}]
#    ├─ 11004.000 [SAMPLE] Integrate.../lulesh.cc} {543}]
#    ├─ 34013.000 [SAMPLE] Integrate.../lulesh.cc} {573}]
#    ├─ 8003.000 [SAMPLE] Integrate.../lulesh.cc} {575}]
#    ├─ 38029.000 [SAMPLE] Integrate.../lulesh.cc} {576}]
#    ├─ 36015.000 [SAMPLE] Integrate.../lulesh.cc} {577}]
#    ├─ 1001.000 [SAMPLE] Integrate.../lulesh.cc} {579}]
#    ├─ 73016.000 [SAMPLE] SQRT(doub...SH/lulesh.h} {44}]
#    ├─ 23011.000 [SAMPLE] SumElemFa.../lulesh.cc} {391}]
#    ├─ 11004.000 [SAMPLE] SumElemFa.../lulesh.cc} {392}]
#    ├─ 12005.000 [SAMPLE] SumElemFa.../lulesh.cc} {393}]
#    ├─ 7005.000 [SAMPLE] SumElemFa.../lulesh.cc} {394}]
#    ├─ 13005.000 [SAMPLE] SumElemFa.../lulesh.cc} {395}]
#    ├─ 15006.000 [SAMPLE] SumElemFa.../lulesh.cc} {396}]
#    ├─ 6003.000 [SAMPLE] SumElemFa.../lulesh.cc} {397}]
#    ├─ 40009.000 [SAMPLE] SumElemFa.../lulesh.cc} {398}]
#    ├─ 16010.000 [SAMPLE] SumElemFa.../lulesh.cc} {399}]
#    ├─ 9004.000 [SAMPLE] SumElemFa.../lulesh.cc} {401}]
#    ├─ 11005.000 [SAMPLE] SumElemFa.../lulesh.cc} {402}]
#    ├─ 25010.000 [SAMPLE] SumElemFa.../lulesh.cc} {403}]
#    ├─ 4003.000 [SAMPLE] SumElemFa.../lulesh.cc} {404}]
#    ├─ 5003.000 [SAMPLE] SumElemFa.../lulesh.cc} {406}]
#    ├─ 3001.000 [SAMPLE] SumElemFa.../lulesh.cc} {407}]
#    ├─ 7005.000 [SAMPLE] SumElemFa.../lulesh.cc} {408}]
#    ├─ 8008.000 [SAMPLE] SumElemFa.../lulesh.cc} {409}]
#    ├─ 5003.000 [SAMPLE] SumElemFa.../lulesh.cc} {411}]
#    ├─ 5003.000 [SAMPLE] SumElemFa.../lulesh.cc} {412}]
#    ├─ 6004.000 [SAMPLE] SumElemFa.../lulesh.cc} {413}]
#    ├─ 4003.000 [SAMPLE] SumElemFa.../lulesh.cc} {414}]
#    ├─ 4002.000 [SAMPLE] SumElemSt.../lulesh.cc} {485}]
#    ├─ 24824.000 [SAMPLE] SumElemSt.../lulesh.cc} {486}]
#    ├─ 1001.000 [SAMPLE] SumElemSt.../lulesh.cc} {487}]
#    ├─ 5996.000 [SAMPLE] SumElemSt.../lulesh.cc} {488}]
#    ├─ 1000.000 [SAMPLE] TauIntern...TauCppAPI.h} {65}]
#    ├─ 2999.000 [SAMPLE] Tau_globa...auCAPI.cpp} {344}]
#    ├─ 1000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {347}]
#    ├─ 9000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {309}]
#    ├─ 1000.000 [SAMPLE] Tau_memor...Memory.cpp} {968}]
#    ├─ 18000.000 [SAMPLE] Tau_memor...Memory.cpp} {957}]
#    ├─ 21997.000 [SAMPLE] Tau_stack...auCAPI.cpp} {236}]
#    ├─ 2000.000 [SAMPLE] UNRESOLVE...SH/build/lulesh2.0
#    ├─ 6999.000 [SAMPLE] UNRESOLVE...-ompt-v5-openmp.so
#    ├─ 11000.000 [SAMPLE] UNRESOLVE...openmp/libiomp5.so
#    ├─ 5000.000 [SAMPLE] UpdateVol...lulesh.cc} {2419}]
#    ├─ 2000.000 [SAMPLE] UpdateVol...lulesh.cc} {2420}]
#    ├─ 67030.000 [SAMPLE] VoluDer [.../lulesh.cc} {603}]
#    ├─ 21014.000 [SAMPLE] VoluDer [.../lulesh.cc} {604}]
#    ├─ 41022.000 [SAMPLE] VoluDer [.../lulesh.cc} {605}]
#    ├─ 33019.000 [SAMPLE] VoluDer [.../lulesh.cc} {607}]
#    ├─ 20012.000 [SAMPLE] VoluDer [.../lulesh.cc} {608}]
#    ├─ 36034.000 [SAMPLE] VoluDer [.../lulesh.cc} {609}]
#    ├─ 34012.000 [SAMPLE] VoluDer [.../lulesh.cc} {612}]
#    ├─ 11010.000 [SAMPLE] VoluDer [.../lulesh.cc} {613}]
#    ├─ 28009.000 [SAMPLE] VoluDer [.../lulesh.cc} {614}]
#    ├─ 14007.000 [SAMPLE] VoluDer [.../lulesh.cc} {616}]
#    ├─ 5003.000 [SAMPLE] VoluDer [.../lulesh.cc} {617}]
#    ├─ 9003.000 [SAMPLE] VoluDer [.../lulesh.cc} {618}]
#    ├─ 62974.000 [SAMPLE] __cbrt [{} {0}]
#    ├─ 1000.000 [SAMPLE] __frexp [{} {0}]
#    ├─ 101647.000 [SAMPLE] __kmp_GOM...gsupport.cpp} {0}]
#    ├─ 53856.000 [SAMPLE] __kmp_acq.../libiomp5.so} {0}]
#    ├─ 1000.000 [SAMPLE] __kmp_api..._10_alias [{} {0}]
#    ├─ 37999.000 [SAMPLE] __kmp_api..._parallel [{} {0}]
#    ├─ 16001.000 [SAMPLE] __kmp_api..._10_alias [{} {0}]
#    ├─ 16992.000 [SAMPLE] __kmp_api..._10_alias [{} {0}]
#    ├─ 5000.000 [SAMPLE] __kmp_api...hread_num [{} {0}]
#    ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
#    ├─ 1001.000 [SAMPLE] __kmp_fin...icit_task [{} {0}]
#    ├─ 28861.000 [SAMPLE] __kmp_get...thread_id [{} {0}]
#    ├─ 26905.000 [SAMPLE] __kmp_get...ad_id_reg [{} {0}]
#    ├─ 19996.000 [SAMPLE] __kmp_internal_join [{} {0}]
#    ├─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 9997.000 [SAMPLE] __kmpc_ba.../libiomp5.so} {0}]
#    ├─ 44999.000 [SAMPLE] __kmpc_bo.../libiomp5.so} {0}]
#    ├─ 4999.000 [SAMPLE] __ldexp [{} {0}]
#    ├─ 42750.000 [SAMPLE] __ompt_ge...**, int*) [{} {0}]
#    ├─ 35914.000 [SAMPLE] __ompt_ge...ject(int) [{} {0}]
#    ├─ 1998.000 [SAMPLE] __scalbn [{} {0}]
#    ├─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
#    ├─ 2001.000 [SAMPLE] double co...algobase.h} {225}]
#    ├─ 3003.000 [SAMPLE] double co...algobase.h} {226}]
#    ├─ 1000.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {663}]
#    ├─ 14000.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {678}]
#    ├─ 16002.000 [SAMPLE] std::vect...l_vector.h} {798}]
#    └─ 18002.000 [SAMPLE] std::vect...l_vector.h} {798}]
# 2953.000 OpenMP_Parallel_Re...esh.cc} {1157, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {1157, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    └─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
# 22645.000 OpenMP_Parallel_Re...esh.cc} {2500, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2500, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    └─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
# 66383.000 OpenMP_Parallel_Re...esh.cc} {2075, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2075, 0}]
#    ├─ 9000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {309}]
#    ├─ 18000.000 [SAMPLE] Tau_memor...Memory.cpp} {957}]
#    ├─ 53856.000 [SAMPLE] __kmp_acq.../libiomp5.so} {0}]
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
# 68535.000 OpenMP_Parallel_Re...esh.cc} {2100, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2100, 0}]
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    ├─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
#    └─ 4999.000 [SAMPLE] __ompt_ge...nt, int*) [{} {0}]
# 66916.000 OpenMP_Parallel_Re...esh.cc} {2116, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2116, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 10000.000 [SAMPLE] __kmp_ini...icit_task [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    ├─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
#    ├─ 35914.000 [SAMPLE] __ompt_ge...ject(int) [{} {0}]
#    └─ 4999.000 [SAMPLE] __ompt_ge...nt, int*) [{} {0}]
# 67501.000 OpenMP_Parallel_Re...esh.cc} {2153, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2153, 0}]
#    ├─ 53856.000 [SAMPLE] __kmp_acq.../libiomp5.so} {0}]
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 9007.000 [SAMPLE] __kmp_pop...om_thread [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
# 2591.000 OpenMP_Parallel_Re...esh.cc} {1043, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {1043, 0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    └─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
# 2651.000 OpenMP_Parallel_Re...lesh.cc} {999, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...lesh.cc} {999, 0}]
#    └─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
# 23017.000 OpenMP_Parallel_Re...esh.cc} {2560, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2560, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 28861.000 [SAMPLE] __kmp_get...thread_id [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
# 21182.000 OpenMP_Parallel_Re...esh.cc} {1936, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {1936, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    └─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
# 2091.000 OpenMP_Parallel_Re...esh.cc} {1212, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {1212, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    └─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
# 218060.000 OpenMP_Parallel_Re...esh.cc} {2022, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2022, 0}]
#    ├─ 2999.000 [SAMPLE] Tau_globa...auCAPI.cpp} {344}]
#    ├─ 9000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {309}]
#    ├─ 3999.000 [SAMPLE] Tau_memor...Memory.cpp} {960}]
#    ├─ 21997.000 [SAMPLE] Tau_stack...auCAPI.cpp} {236}]
#    ├─ 11000.000 [SAMPLE] UNRESOLVE...openmp/libiomp5.so
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
# 210603.000 OpenMP_Parallel_Re...esh.cc} {2029, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2029, 0}]
#    ├─ 6999.000 [SAMPLE] UNRESOLVE...-ompt-v5-openmp.so
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 2999.000 [SAMPLE] __kmp_free_team [{} {0}]
#    ├─ 10000.000 [SAMPLE] __kmp_ini...icit_task [{} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    ├─ 4000.000 [SAMPLE] __kmp_sto...trol_word [{} {0}]
#    ├─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
#    └─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
# 21559.000 OpenMP_Parallel_Re...esh.cc} {2187, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2187, 0}]
#    ├─ 6999.000 [SAMPLE] UNRESOLVE...-ompt-v5-openmp.so
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
# 2450.000 OpenMP_Parallel_Re...esh.cc} {2583, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2583, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    └─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
# 2187.000 OpenMP_Parallel_Re...esh.cc} {1188, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {1188, 0}]
#    └─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
# 5711.000 OpenMP_Parallel_Re...esh.cc} {1064, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {1064, 0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    ├─ 989.000 [SAMPLE] __mmap64 [{} {0}]
#    └─ 32725.000 [SAMPLE] _int_malloc [{malloc.c} {0}]
# 2208.000 OpenMP_Parallel_Re...esh.cc} {1077, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {1077, 0}]
#    └─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
# 71912.000 OpenMP_Parallel_Re...esh.cc} {2289, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {2289, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 28861.000 [SAMPLE] __kmp_get...thread_id [{} {0}]
#    ├─ 10000.000 [SAMPLE] __kmp_ini...icit_task [{} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 9007.000 [SAMPLE] __kmp_pop...om_thread [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
# 2112.000 OpenMP_Parallel_Re...esh.cc} {1261, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...esh.cc} {1261, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    └─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
# 97778.000 OpenMP_Parallel_Re...ulesh.h} {118, 0}]
# └─ 0.000 [CONTEXT] OpenMP_P...ulesh.h} {118, 0}]
#    ├─ 53856.000 [SAMPLE] __kmp_acq.../libiomp5.so} {0}]
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    ├─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
#    ├─ 4999.000 [SAMPLE] __ompt_ge...nt, int*) [{} {0}]
#    ├─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
#    └─ 6000.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {223}]
# 11539.000 OpenMP_Sync_Region...esh.cc} {1157, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1157, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1157, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 3981.000 OpenMP_Sync_Region...esh.cc} {2387, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2387, 0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2387, 0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 23606.000 OpenMP_Sync_Region...esh.cc} {2347, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2347, 0}]
# │  ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2347, 0}]
#    ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# 15662.000 OpenMP_Sync_Region...esh.cc} {2500, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2500, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2500, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 225720.000 OpenMP_Sync_Region...esh.cc} {2496, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2496, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2496, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# 79157.000 OpenMP_Sync_Region...esh.cc} {2075, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2075, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2075, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 127331.000 OpenMP_Sync_Region...esh.cc} {2100, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2100, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2100, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 81100.000 OpenMP_Sync_Region...esh.cc} {2116, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2116, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2116, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 79833.000 OpenMP_Sync_Region...esh.cc} {2153, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2153, 0}]
# │  ├─ 1000.000 [SAMPLE] Tau_memor...Memory.cpp} {971}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2153, 0}]
#    ├─ 1000.000 [SAMPLE] Tau_memor...Memory.cpp} {971}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 111737.000 OpenMP_Sync_Region...lesh.cc} {967, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...lesh.cc} {967, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...lesh.cc} {967, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 24423.000 OpenMP_Sync_Region...esh.cc} {1043, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1043, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1043, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 2878.000 OpenMP_Sync_Region...lesh.cc} {999, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...lesh.cc} {999, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...lesh.cc} {999, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 15021.000 OpenMP_Sync_Region...esh.cc} {2560, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2560, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2560, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 247060.000 OpenMP_Sync_Region...esh.cc} {2556, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2556, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2556, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# 31610.000 OpenMP_Sync_Region...esh.cc} {1510, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1510, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1510, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 69896.000 OpenMP_Sync_Region...esh.cc} {1936, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1936, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1936, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 14342.000 OpenMP_Sync_Region...esh.cc} {1212, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1212, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1212, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 291080.000 OpenMP_Sync_Region...esh.cc} {2022, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2022, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  ├─ 19996.000 [SAMPLE] __kmp_internal_join [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2022, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    ├─ 19996.000 [SAMPLE] __kmp_internal_join [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 300433.000 OpenMP_Sync_Region...esh.cc} {2029, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2029, 0}]
# │  ├─ 3999.000 [SAMPLE] Tau_memor...Memory.cpp} {960}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  ├─ 19996.000 [SAMPLE] __kmp_internal_join [{} {0}]
# │  ├─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# │  ├─ 5000.000 [SAMPLE] __kmp_task_team_wait [{} {0}]
# │  └─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2029, 0}]
#    ├─ 3999.000 [SAMPLE] Tau_memor...Memory.cpp} {960}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    ├─ 19996.000 [SAMPLE] __kmp_internal_join [{} {0}]
#    ├─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
#    ├─ 5000.000 [SAMPLE] __kmp_task_team_wait [{} {0}]
#    └─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
# 21257.000 OpenMP_Sync_Region...esh.cc} {1977, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1977, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1977, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 43115.000 OpenMP_Sync_Region...esh.cc} {2187, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2187, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2187, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 3121.000 OpenMP_Sync_Region...esh.cc} {2583, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2583, 0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2583, 0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 6781.000 OpenMP_Sync_Region...esh.cc} {1064, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1064, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1064, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 13271.000 OpenMP_Sync_Region...esh.cc} {1077, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1077, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1077, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 69327.000 OpenMP_Sync_Region...esh.cc} {2289, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2289, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2289, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 503149.000 OpenMP_Sync_Region...esh.cc} {2263, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2263, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  ├─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# │  └─ 999.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {771}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {2263, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    ├─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
#    └─ 999.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {771}]
# 16092.000 OpenMP_Sync_Region...lesh.cc} {562, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...lesh.cc} {562, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...lesh.cc} {562, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 12655.000 OpenMP_Sync_Region...esh.cc} {1261, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1261, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...esh.cc} {1261, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 183726.000 OpenMP_Sync_Region...ulesh.h} {118, 0}]
# ├─ 0.000 [CONTEXT] OpenMP_S...ulesh.h} {118, 0}]
# │  ├─ 9000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {309}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 0.000 [CONTEXT] OpenMP_S...ulesh.h} {118, 0}]
#    ├─ 9000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {309}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
#
# Legend (Metric: exclusive_time)
# █ 6744285.90 - 7493651.00
# █ 5245555.70 - 6744285.90
# █ 3746825.50 - 5245555.70
# █ 2248095.30 - 3746825.50
# █ 749365.10 - 2248095.30
# █ 0.00 - 749365.10
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
print(gf.tree(color=True, metric_column="inclusive_time"))
# Out:
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.2.0
#
# 12513680.000 .TAU application
# └─ 1211132.000 [CONTEXT] .TAU application
#    ├─ 8003.000 [SAMPLE] CalcElemV...lulesh.cc} {1341}]
#    ├─ 2000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2075}]
#    ├─ 1005.000 [SAMPLE] CalcMonot...lulesh.cc} {1936}]
#    ├─ 4000.000 [SAMPLE] CalcPress...lulesh.cc} {2022}]
#    ├─ 18000.000 [SAMPLE] CalcPress...lulesh.cc} {2029}]
#    ├─ 851.000 [SAMPLE] CalcQForE...lulesh.cc} {1995}]
#    ├─ 22851.000 [SAMPLE] CalcQForE...lulesh.cc} {1996}]
#    ├─ 1001.000 [SAMPLE] Domain::D...sh-init.cc} {174}]
#    ├─ 1001.000 [SAMPLE] Domain::S...sh-init.cc} {291}]
#    ├─ 1002.000 [SAMPLE] Domain::S...sh-init.cc} {316}]
#    ├─ 1000.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2238}]
#    ├─ 999.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2289}]
#    ├─ 18000.000 [SAMPLE] Tau_memor...Memory.cpp} {957}]
#    ├─ 3994.000 [SAMPLE] _IO_vfprintf_internal [{} {0}]
#    ├─ 998.000 [SAMPLE] __GI__IO_sputbackc [{} {0}]
#    ├─ 1365.000 [SAMPLE] __GI___fork [{} {0}]
#    ├─ 12959.000 [SAMPLE] __GI___libc_free [{} {0}]
#    ├─ 63612.000 [SAMPLE] __GI___libc_malloc [{} {0}]
#    ├─ 1999.000 [SAMPLE] __GI___mempcpy [{} {0}]
#    ├─ 4000.000 [SAMPLE] __GI___printf_fp_l [{} {0}]
#    ├─ 1000.000 [SAMPLE] __GI_getenv [{} {0}]
#    ├─ 317313.000 [SAMPLE] __brk [{} {0}]
#    ├─ 5999.000 [SAMPLE] __gnu_cxx...algobase.h} {754}]
#    ├─ 998.000 [SAMPLE] __gnu_cxx...algobase.h} {754}]
#    ├─ 1004.000 [SAMPLE] __ioctl [{} {0}]
#    ├─ 101647.000 [SAMPLE] __kmp_GOM...gsupport.cpp} {0}]
#    ├─ 37999.000 [SAMPLE] __kmp_api..._parallel [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 28861.000 [SAMPLE] __kmp_get...thread_id [{} {0}]
#    ├─ 26905.000 [SAMPLE] __kmp_get...ad_id_reg [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 3999.000 [SAMPLE] __kmpc_ok.../libiomp5.so} {0}]
#    ├─ 1008.000 [SAMPLE] __libc_recv [{} {0}]
#    ├─ 3053.000 [SAMPLE] __munmap [{} {0}]
#    ├─ 1002.000 [SAMPLE] __nanosleep_nocancel [{} {0}]
#    ├─ 42750.000 [SAMPLE] __ompt_ge...**, int*) [{} {0}]
#    ├─ 35914.000 [SAMPLE] __ompt_ge...ject(int) [{} {0}]
#    ├─ 1003.000 [SAMPLE] __open [{} {0}]
#    ├─ 39042.000 [SAMPLE] __pthread_cond_wait [{} {0}]
#    ├─ 997.000 [SAMPLE] __random [{} {0}]
#    ├─ 1996.000 [SAMPLE] __read [{} {0}]
#    ├─ 205056.000 [SAMPLE] __read_nocancel [{} {0}]
#    ├─ 1000.000 [SAMPLE] __strchrnul [{} {0}]
#    ├─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
#    ├─ 26078.000 [SAMPLE] __write_nocancel [{} {0}]
#    ├─ 988.000 [SAMPLE] _dl_check_caller [{} {0}]
#    ├─ 996.000 [SAMPLE] _dl_name_match_p [{} {0}]
#    ├─ 66059.000 [SAMPLE] _int_free [{malloc.c} {0}]
#    ├─ 32725.000 [SAMPLE] _int_malloc [{malloc.c} {0}]
#    ├─ 1007.000 [SAMPLE] _xstat [{} {0}]
#    ├─ 2994.000 [SAMPLE] check_mat...{dl-lookup.c} {0}]
#    ├─ 19950.000 [SAMPLE] do_lookup...{dl-lookup.c} {0}]
#    ├─ 1000.000 [SAMPLE] group_reg..._var_group.c} {0}]
#    ├─ 26004.000 [SAMPLE] malloc_co...e [{malloc.c} {0}]
#    ├─ 1001.000 [SAMPLE] mca_base_...al.so.40.0.0} {0}]
#    ├─ 994.000 [SAMPLE] memset [{} {0}]
#    ├─ 1004.000 [SAMPLE] munmap [{} {0}]
#    ├─ 1001.000 [SAMPLE] ompi_data...pi.so.40.0.0} {0}]
#    ├─ 3999.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {179}]
#    ├─ 1002.000 [SAMPLE] std::char...r_traits.h} {350}]
#    ├─ 7000.000 [SAMPLE] std::ctyp...e_facets.h} {901}]
#    ├─ 1999.000 [SAMPLE] strcmp [{} {0}]
#    └─ 30020.000 [SAMPLE] sysmalloc [{malloc.c} {0}]
# 10124249.000 OpenMP_Implicit_Task
# └─ 5989397.000 [CONTEXT] OpenMP_Implicit_Task
#    ├─ 2635.000 [SAMPLE] ApplyMate...lulesh.cc} {2343}]
#    ├─ 2849.000 [SAMPLE] ApplyMate...lulesh.cc} {2350}]
#    ├─ 1835.000 [SAMPLE] ApplyMate...lulesh.cc} {2351}]
#    ├─ 930.000 [SAMPLE] ApplyMate...lulesh.cc} {2359}]
#    ├─ 1841.000 [SAMPLE] ApplyMate...lulesh.cc} {2369}]
#    ├─ 1871.000 [SAMPLE] ApplyMate...lulesh.cc} {2375}]
#    ├─ 4002.000 [SAMPLE] AreaFace ...lulesh.cc} {1378}]
#    ├─ 12009.000 [SAMPLE] AreaFace ...lulesh.cc} {1379}]
#    ├─ 9006.000 [SAMPLE] AreaFace ...lulesh.cc} {1380}]
#    ├─ 3002.000 [SAMPLE] AreaFace ...lulesh.cc} {1383}]
#    ├─ 2000.000 [SAMPLE] AreaFace ...lulesh.cc} {1384}]
#    ├─ 2997.000 [SAMPLE] AreaFace ...lulesh.cc} {1385}]
#    ├─ 3002.000 [SAMPLE] AreaFace ...lulesh.cc} {1386}]
#    ├─ 15013.000 [SAMPLE] AreaFace ...lulesh.cc} {1387}]
#    ├─ 2017.000 [SAMPLE] CalcAccel...lulesh.cc} {1145}]
#    ├─ 3998.000 [SAMPLE] CalcAccel...lulesh.cc} {1146}]
#    ├─ 4000.000 [SAMPLE] CalcAccel...lulesh.cc} {1147}]
#    ├─ 999.000 [SAMPLE] CalcCoura...lulesh.cc} {2462}]
#    ├─ 4000.000 [SAMPLE] CalcCoura...lulesh.cc} {2479}]
#    ├─ 6000.000 [SAMPLE] CalcCoura...lulesh.cc} {2486}]
#    ├─ 1000.000 [SAMPLE] CalcCoura...lulesh.cc} {2488}]
#    ├─ 7005.000 [SAMPLE] CalcElemC...lulesh.cc} {1432}]
#    ├─ 10999.000 [SAMPLE] CalcElemF.../lulesh.cc} {674}]
#    ├─ 5997.000 [SAMPLE] CalcElemF.../lulesh.cc} {675}]
#    ├─ 7999.000 [SAMPLE] CalcElemF.../lulesh.cc} {676}]
#    ├─ 6000.000 [SAMPLE] CalcElemF.../lulesh.cc} {677}]
#    ├─ 8999.000 [SAMPLE] CalcElemF.../lulesh.cc} {679}]
#    ├─ 29987.000 [SAMPLE] CalcElemF.../lulesh.cc} {680}]
#    ├─ 26999.000 [SAMPLE] CalcElemF.../lulesh.cc} {681}]
#    ├─ 13998.000 [SAMPLE] CalcElemF.../lulesh.cc} {682}]
#    ├─ 1998.000 [SAMPLE] CalcElemF.../lulesh.cc} {684}]
#    ├─ 4998.000 [SAMPLE] CalcElemF.../lulesh.cc} {685}]
#    ├─ 12000.000 [SAMPLE] CalcElemF.../lulesh.cc} {686}]
#    ├─ 4000.000 [SAMPLE] CalcElemF.../lulesh.cc} {688}]
#    ├─ 10998.000 [SAMPLE] CalcElemF.../lulesh.cc} {690}]
#    ├─ 14000.000 [SAMPLE] CalcElemF.../lulesh.cc} {691}]
#    ├─ 16994.000 [SAMPLE] CalcElemF.../lulesh.cc} {692}]
#    ├─ 24996.000 [SAMPLE] CalcElemF.../lulesh.cc} {693}]
#    ├─ 999.000 [SAMPLE] CalcElemF.../lulesh.cc} {695}]
#    ├─ 3001.000 [SAMPLE] CalcElemF.../lulesh.cc} {696}]
#    ├─ 7999.000 [SAMPLE] CalcElemF.../lulesh.cc} {697}]
#    ├─ 1000.000 [SAMPLE] CalcElemF.../lulesh.cc} {698}]
#    ├─ 8996.000 [SAMPLE] CalcElemF.../lulesh.cc} {699}]
#    ├─ 999.000 [SAMPLE] CalcElemF.../lulesh.cc} {701}]
#    ├─ 14983.000 [SAMPLE] CalcElemF.../lulesh.cc} {702}]
#    ├─ 13996.000 [SAMPLE] CalcElemF.../lulesh.cc} {703}]
#    ├─ 2997.000 [SAMPLE] CalcElemF.../lulesh.cc} {704}]
#    ├─ 8006.000 [SAMPLE] CalcElemN.../lulesh.cc} {427}]
#    ├─ 17006.000 [SAMPLE] CalcElemN.../lulesh.cc} {428}]
#    ├─ 13001.000 [SAMPLE] CalcElemN.../lulesh.cc} {430}]
#    ├─ 8005.000 [SAMPLE] CalcElemS.../lulesh.cc} {319}]
#    ├─ 8003.000 [SAMPLE] CalcElemS.../lulesh.cc} {320}]
#    ├─ 6006.000 [SAMPLE] CalcElemS.../lulesh.cc} {323}]
#    ├─ 2002.000 [SAMPLE] CalcElemS.../lulesh.cc} {324}]
#    ├─ 8002.000 [SAMPLE] CalcElemS.../lulesh.cc} {325}]
#    ├─ 16012.000 [SAMPLE] CalcElemS.../lulesh.cc} {327}]
#    ├─ 20007.000 [SAMPLE] CalcElemS.../lulesh.cc} {329}]
#    ├─ 2001.000 [SAMPLE] CalcElemS.../lulesh.cc} {332}]
#    ├─ 9001.000 [SAMPLE] CalcElemS.../lulesh.cc} {333}]
#    ├─ 6004.000 [SAMPLE] CalcElemS.../lulesh.cc} {334}]
#    ├─ 5003.000 [SAMPLE] CalcElemS.../lulesh.cc} {336}]
#    ├─ 7002.000 [SAMPLE] CalcElemS.../lulesh.cc} {337}]
#    ├─ 3002.000 [SAMPLE] CalcElemS.../lulesh.cc} {338}]
#    ├─ 2002.000 [SAMPLE] CalcElemS.../lulesh.cc} {340}]
#    ├─ 3002.000 [SAMPLE] CalcElemS.../lulesh.cc} {342}]
#    ├─ 6002.000 [SAMPLE] CalcElemS.../lulesh.cc} {348}]
#    ├─ 20004.000 [SAMPLE] CalcElemS.../lulesh.cc} {350}]
#    ├─ 2001.000 [SAMPLE] CalcElemS.../lulesh.cc} {351}]
#    ├─ 1001.000 [SAMPLE] CalcElemS.../lulesh.cc} {354}]
#    ├─ 1001.000 [SAMPLE] CalcElemS.../lulesh.cc} {355}]
#    ├─ 2002.000 [SAMPLE] CalcElemS.../lulesh.cc} {357}]
#    ├─ 8001.000 [SAMPLE] CalcElemS.../lulesh.cc} {359}]
#    ├─ 1001.000 [SAMPLE] CalcElemS.../lulesh.cc} {360}]
#    ├─ 15007.000 [SAMPLE] CalcElemS.../lulesh.cc} {363}]
#    ├─ 2003.000 [SAMPLE] CalcElemS.../lulesh.cc} {366}]
#    ├─ 9002.000 [SAMPLE] CalcElemS.../lulesh.cc} {367}]
#    ├─ 1001.000 [SAMPLE] CalcElemS.../lulesh.cc} {368}]
#    ├─ 2001.000 [SAMPLE] CalcElemS.../lulesh.cc} {370}]
#    ├─ 1001.000 [SAMPLE] CalcElemS.../lulesh.cc} {371}]
#    ├─ 2002.000 [SAMPLE] CalcElemS.../lulesh.cc} {373}]
#    ├─ 3002.000 [SAMPLE] CalcElemS.../lulesh.cc} {376}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1447}]
#    ├─ 2001.000 [SAMPLE] CalcElemV...lulesh.cc} {1453}]
#    ├─ 7006.000 [SAMPLE] CalcElemV...lulesh.cc} {1458}]
#    ├─ 1000.000 [SAMPLE] CalcElemV...lulesh.cc} {1464}]
#    ├─ 1002.000 [SAMPLE] CalcElemV...lulesh.cc} {1465}]
#    ├─ 999.000 [SAMPLE] CalcElemV...lulesh.cc} {1291}]
#    ├─ 3002.000 [SAMPLE] CalcElemV...lulesh.cc} {1295}]
#    ├─ 2002.000 [SAMPLE] CalcElemV...lulesh.cc} {1297}]
#    ├─ 3004.000 [SAMPLE] CalcElemV...lulesh.cc} {1298}]
#    ├─ 2002.000 [SAMPLE] CalcElemV...lulesh.cc} {1301}]
#    ├─ 1000.000 [SAMPLE] CalcElemV...lulesh.cc} {1311}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1313}]
#    ├─ 998.000 [SAMPLE] CalcElemV...lulesh.cc} {1315}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1322}]
#    ├─ 3002.000 [SAMPLE] CalcElemV...lulesh.cc} {1323}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1326}]
#    ├─ 2002.000 [SAMPLE] CalcElemV...lulesh.cc} {1329}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1330}]
#    ├─ 3004.000 [SAMPLE] CalcElemV...lulesh.cc} {1333}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1334}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1335}]
#    ├─ 8003.000 [SAMPLE] CalcElemV...lulesh.cc} {1341}]
#    ├─ 1001.000 [SAMPLE] CalcElemV...lulesh.cc} {1347}]
#    ├─ 2001.000 [SAMPLE] CalcElemV...lulesh.cc} {1353}]
#    ├─ 2001.000 [SAMPLE] CalcElemV...lulesh.cc} {1362}]
#    ├─ 2000.000 [SAMPLE] CalcElemV...lulesh.cc} {1363}]
#    ├─ 1997.000 [SAMPLE] CalcElemV...lulesh.cc} {1366}]
#    ├─ 38996.000 [SAMPLE] CalcEnerg...lulesh.cc} {2064}]
#    ├─ 20998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2065}]
#    ├─ 53995.000 [SAMPLE] CalcEnerg...lulesh.cc} {2068}]
#    ├─ 10999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2075}]
#    ├─ 6000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2077}]
#    ├─ 19998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2079}]
#    ├─ 26997.000 [SAMPLE] CalcEnerg...lulesh.cc} {2083}]
#    ├─ 28797.000 [SAMPLE] CalcEnerg...lulesh.cc} {2084}]
#    ├─ 40000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2086}]
#    ├─ 11000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2087}]
#    ├─ 44910.000 [SAMPLE] CalcEnerg...lulesh.cc} {2092}]
#    ├─ 34992.000 [SAMPLE] CalcEnerg...lulesh.cc} {2095}]
#    ├─ 39999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2096}]
#    ├─ 12999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2097}]
#    ├─ 1000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2100}]
#    ├─ 32995.000 [SAMPLE] CalcEnerg...lulesh.cc} {2103}]
#    ├─ 4998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2105}]
#    ├─ 5000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2106}]
#    ├─ 21000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2109}]
#    ├─ 9999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2116}]
#    ├─ 64987.000 [SAMPLE] CalcEnerg...lulesh.cc} {2122}]
#    ├─ 10008.000 [SAMPLE] CalcEnerg...lulesh.cc} {2123}]
#    ├─ 18999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2126}]
#    ├─ 19000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2127}]
#    ├─ 15998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2129}]
#    ├─ 14000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2135}]
#    ├─ 22766.000 [SAMPLE] CalcEnerg...lulesh.cc} {2138}]
#    ├─ 32998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2139}]
#    ├─ 12998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2140}]
#    ├─ 15989.000 [SAMPLE] CalcEnerg...lulesh.cc} {2143}]
#    ├─ 52992.000 [SAMPLE] CalcEnerg...lulesh.cc} {2146}]
#    ├─ 1999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2153}]
#    ├─ 17015.000 [SAMPLE] CalcEnerg...lulesh.cc} {2157}]
#    ├─ 7000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2158}]
#    ├─ 26997.000 [SAMPLE] CalcEnerg...lulesh.cc} {2159}]
#    ├─ 48998.000 [SAMPLE] CalcEnerg...lulesh.cc} {2161}]
#    ├─ 4000.000 [SAMPLE] CalcEnerg...lulesh.cc} {2162}]
#    ├─ 7999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2167}]
#    ├─ 12999.000 [SAMPLE] CalcEnerg...lulesh.cc} {2169}]
#    ├─ 2001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {782}]
#    ├─ 3999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {794}]
#    ├─ 8000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {799}]
#    ├─ 11000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {800}]
#    ├─ 3996.000 [SAMPLE] CalcFBHou.../lulesh.cc} {801}]
#    ├─ 22994.000 [SAMPLE] CalcFBHou.../lulesh.cc} {802}]
#    ├─ 3997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {805}]
#    ├─ 1998.000 [SAMPLE] CalcFBHou.../lulesh.cc} {806}]
#    ├─ 1000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {807}]
#    ├─ 21988.000 [SAMPLE] CalcFBHou.../lulesh.cc} {808}]
#    ├─ 8000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {810}]
#    ├─ 7983.000 [SAMPLE] CalcFBHou.../lulesh.cc} {811}]
#    ├─ 12996.000 [SAMPLE] CalcFBHou.../lulesh.cc} {812}]
#    ├─ 4000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {813}]
#    ├─ 13996.000 [SAMPLE] CalcFBHou.../lulesh.cc} {814}]
#    ├─ 17992.000 [SAMPLE] CalcFBHou.../lulesh.cc} {816}]
#    ├─ 21001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {817}]
#    ├─ 6999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {818}]
#    ├─ 36995.000 [SAMPLE] CalcFBHou.../lulesh.cc} {820}]
#    ├─ 28000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {821}]
#    ├─ 4997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {822}]
#    ├─ 3000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {824}]
#    ├─ 16997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {825}]
#    ├─ 13995.000 [SAMPLE] CalcFBHou.../lulesh.cc} {828}]
#    ├─ 4997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {829}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {830}]
#    ├─ 2997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {832}]
#    ├─ 2001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {833}]
#    ├─ 6997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {834}]
#    ├─ 3997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {836}]
#    ├─ 6993.000 [SAMPLE] CalcFBHou.../lulesh.cc} {838}]
#    ├─ 15999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {840}]
#    ├─ 3997.000 [SAMPLE] CalcFBHou.../lulesh.cc} {841}]
#    ├─ 3000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {842}]
#    ├─ 2000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {844}]
#    ├─ 1000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {845}]
#    ├─ 9000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {846}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {854}]
#    ├─ 3000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {873}]
#    ├─ 7000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {876}]
#    ├─ 1998.000 [SAMPLE] CalcFBHou.../lulesh.cc} {879}]
#    ├─ 1001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {888}]
#    ├─ 998.000 [SAMPLE] CalcFBHou.../lulesh.cc} {889}]
#    ├─ 1998.000 [SAMPLE] CalcFBHou.../lulesh.cc} {890}]
#    ├─ 6992.000 [SAMPLE] CalcFBHou.../lulesh.cc} {893}]
#    ├─ 1000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {903}]
#    ├─ 1000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {904}]
#    ├─ 2001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {908}]
#    ├─ 3001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {915}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {916}]
#    ├─ 1000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {917}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {924}]
#    ├─ 7000.000 [SAMPLE] CalcFBHou.../lulesh.cc} {926}]
#    ├─ 1999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {928}]
#    ├─ 5999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {929}]
#    ├─ 89049.000 [SAMPLE] CalcFBHou.../lulesh.cc} {930}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {974}]
#    ├─ 14001.000 [SAMPLE] CalcFBHou.../lulesh.cc} {977}]
#    ├─ 3998.000 [SAMPLE] CalcFBHou.../lulesh.cc} {979}]
#    ├─ 11002.000 [SAMPLE] CalcFBHou.../lulesh.cc} {980}]
#    ├─ 12999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {981}]
#    ├─ 999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {984}]
#    ├─ 4999.000 [SAMPLE] CalcFBHou.../lulesh.cc} {985}]
#    ├─ 9016.000 [SAMPLE] CalcForce...lulesh.cc} {1116}]
#    ├─ 15029.000 [SAMPLE] CalcForce...lulesh.cc} {1117}]
#    ├─ 7008.000 [SAMPLE] CalcForce...lulesh.cc} {1118}]
#    ├─ 6002.000 [SAMPLE] CalcHourg...lulesh.cc} {1023}]
#    ├─ 8951.000 [SAMPLE] CalcHourg...lulesh.cc} {1025}]
#    ├─ 15008.000 [SAMPLE] CalcHourg...lulesh.cc} {1026}]
#    ├─ 6003.000 [SAMPLE] CalcHourg...lulesh.cc} {1027}]
#    ├─ 39042.000 [SAMPLE] CalcHourg...lulesh.cc} {1028}]
#    ├─ 14005.000 [SAMPLE] CalcHourg...lulesh.cc} {1031}]
#    ├─ 15003.000 [SAMPLE] CalcHourg...lulesh.cc} {1034}]
#    ├─ 1000.000 [SAMPLE] CalcHydro...lulesh.cc} {2544}]
#    ├─ 2981.000 [SAMPLE] CalcHydro...lulesh.cc} {2546}]
#    ├─ 2000.000 [SAMPLE] CalcHydro...lulesh.cc} {2547}]
#    ├─ 4000.000 [SAMPLE] CalcHydro...lulesh.cc} {2550}]
#    ├─ 1001.000 [SAMPLE] CalcKinem...lulesh.cc} {1531}]
#    ├─ 2001.000 [SAMPLE] CalcKinem...lulesh.cc} {1532}]
#    ├─ 4001.000 [SAMPLE] CalcKinem...lulesh.cc} {1533}]
#    ├─ 2001.000 [SAMPLE] CalcKinem...lulesh.cc} {1534}]
#    ├─ 3002.000 [SAMPLE] CalcKinem...lulesh.cc} {1537}]
#    ├─ 2002.000 [SAMPLE] CalcKinem...lulesh.cc} {1541}]
#    ├─ 2000.000 [SAMPLE] CalcKinem...lulesh.cc} {1544}]
#    ├─ 2002.000 [SAMPLE] CalcKinem...lulesh.cc} {1545}]
#    ├─ 3002.000 [SAMPLE] CalcKinem...lulesh.cc} {1546}]
#    ├─ 1001.000 [SAMPLE] CalcKinem...lulesh.cc} {1550}]
#    ├─ 3001.000 [SAMPLE] CalcKinem...lulesh.cc} {1552}]
#    ├─ 4002.000 [SAMPLE] CalcKinem...lulesh.cc} {1553}]
#    ├─ 5005.000 [SAMPLE] CalcKinem...lulesh.cc} {1554}]
#    ├─ 2001.000 [SAMPLE] CalcKinem...lulesh.cc} {1564}]
#    ├─ 2001.000 [SAMPLE] CalcLagra...lulesh.cc} {1588}]
#    ├─ 7007.000 [SAMPLE] CalcLagra...lulesh.cc} {1593}]
#    ├─ 1000.000 [SAMPLE] CalcLagra...lulesh.cc} {1594}]
#    ├─ 8006.000 [SAMPLE] CalcLagra...lulesh.cc} {1595}]
#    ├─ 2002.000 [SAMPLE] CalcLagra...lulesh.cc} {1598}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1644}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1646}]
#    ├─ 1000.000 [SAMPLE] CalcMonot...lulesh.cc} {1650}]
#    ├─ 999.000 [SAMPLE] CalcMonot...lulesh.cc} {1661}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1670}]
#    ├─ 3001.000 [SAMPLE] CalcMonot...lulesh.cc} {1672}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1676}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1680}]
#    ├─ 2001.000 [SAMPLE] CalcMonot...lulesh.cc} {1686}]
#    ├─ 4003.000 [SAMPLE] CalcMonot...lulesh.cc} {1688}]
#    ├─ 5005.000 [SAMPLE] CalcMonot...lulesh.cc} {1691}]
#    ├─ 5796.000 [SAMPLE] CalcMonot...lulesh.cc} {1692}]
#    ├─ 3002.000 [SAMPLE] CalcMonot...lulesh.cc} {1693}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1696}]
#    ├─ 3003.000 [SAMPLE] CalcMonot...lulesh.cc} {1697}]
#    ├─ 3003.000 [SAMPLE] CalcMonot...lulesh.cc} {1699}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1700}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1701}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1706}]
#    ├─ 11008.000 [SAMPLE] CalcMonot...lulesh.cc} {1709}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1711}]
#    ├─ 13019.000 [SAMPLE] CalcMonot...lulesh.cc} {1715}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1716}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1717}]
#    ├─ 1000.000 [SAMPLE] CalcMonot...lulesh.cc} {1723}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1727}]
#    ├─ 4004.000 [SAMPLE] CalcMonot...lulesh.cc} {1733}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1734}]
#    ├─ 3885.000 [SAMPLE] CalcMonot...lulesh.cc} {1735}]
#    ├─ 5004.000 [SAMPLE] CalcMonot...lulesh.cc} {1737}]
#    ├─ 1000.000 [SAMPLE] CalcMonot...lulesh.cc} {1743}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1745}]
#    ├─ 2001.000 [SAMPLE] CalcMonot...lulesh.cc} {1747}]
#    ├─ 1768.000 [SAMPLE] CalcMonot...lulesh.cc} {1749}]
#    ├─ 8009.000 [SAMPLE] CalcMonot...lulesh.cc} {1751}]
#    ├─ 2002.000 [SAMPLE] CalcMonot...lulesh.cc} {1753}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1755}]
#    ├─ 1629.000 [SAMPLE] CalcMonot...lulesh.cc} {1772}]
#    ├─ 3002.000 [SAMPLE] CalcMonot...lulesh.cc} {1775}]
#    ├─ 1907.000 [SAMPLE] CalcMonot...lulesh.cc} {1781}]
#    ├─ 2814.000 [SAMPLE] CalcMonot...lulesh.cc} {1793}]
#    ├─ 1000.000 [SAMPLE] CalcMonot...lulesh.cc} {1805}]
#    ├─ 1770.000 [SAMPLE] CalcMonot...lulesh.cc} {1811}]
#    ├─ 1841.000 [SAMPLE] CalcMonot...lulesh.cc} {1812}]
#    ├─ 2826.000 [SAMPLE] CalcMonot...lulesh.cc} {1813}]
#    ├─ 3616.000 [SAMPLE] CalcMonot...lulesh.cc} {1817}]
#    ├─ 816.000 [SAMPLE] CalcMonot...lulesh.cc} {1819}]
#    ├─ 6832.000 [SAMPLE] CalcMonot...lulesh.cc} {1829}]
#    ├─ 1910.000 [SAMPLE] CalcMonot...lulesh.cc} {1831}]
#    ├─ 902.000 [SAMPLE] CalcMonot...lulesh.cc} {1843}]
#    ├─ 1807.000 [SAMPLE] CalcMonot...lulesh.cc} {1850}]
#    ├─ 1789.000 [SAMPLE] CalcMonot...lulesh.cc} {1851}]
#    ├─ 798.000 [SAMPLE] CalcMonot...lulesh.cc} {1854}]
#    ├─ 1001.000 [SAMPLE] CalcMonot...lulesh.cc} {1866}]
#    ├─ 5181.000 [SAMPLE] CalcMonot...lulesh.cc} {1868}]
#    ├─ 1944.000 [SAMPLE] CalcMonot...lulesh.cc} {1882}]
#    ├─ 841.000 [SAMPLE] CalcMonot...lulesh.cc} {1894}]
#    ├─ 1831.000 [SAMPLE] CalcMonot...lulesh.cc} {1897}]
#    ├─ 2588.000 [SAMPLE] CalcMonot...lulesh.cc} {1898}]
#    ├─ 1794.000 [SAMPLE] CalcMonot...lulesh.cc} {1899}]
#    ├─ 4841.000 [SAMPLE] CalcMonot...lulesh.cc} {1901}]
#    ├─ 1000.000 [SAMPLE] CalcMonot...lulesh.cc} {1907}]
#    ├─ 848.000 [SAMPLE] CalcMonot...lulesh.cc} {1908}]
#    ├─ 831.000 [SAMPLE] CalcMonot...lulesh.cc} {1912}]
#    ├─ 784.000 [SAMPLE] CalcMonot...lulesh.cc} {1914}]
#    ├─ 2615.000 [SAMPLE] CalcMonot...lulesh.cc} {1918}]
#    ├─ 2001.000 [SAMPLE] CalcPosit...lulesh.cc} {1215}]
#    ├─ 2002.000 [SAMPLE] CalcPosit...lulesh.cc} {1216}]
#    ├─ 3003.000 [SAMPLE] CalcPosit...lulesh.cc} {1217}]
#    ├─ 8999.000 [SAMPLE] CalcPress...lulesh.cc} {2022}]
#    ├─ 351733.000 [SAMPLE] CalcPress...lulesh.cc} {2025}]
#    ├─ 208637.000 [SAMPLE] CalcPress...lulesh.cc} {2026}]
#    ├─ 9999.000 [SAMPLE] CalcPress...lulesh.cc} {2029}]
#    ├─ 18967.000 [SAMPLE] CalcPress...lulesh.cc} {2031}]
#    ├─ 12010.000 [SAMPLE] CalcPress...lulesh.cc} {2033}]
#    ├─ 31995.000 [SAMPLE] CalcPress...lulesh.cc} {2035}]
#    ├─ 19000.000 [SAMPLE] CalcPress...lulesh.cc} {2036}]
#    ├─ 32999.000 [SAMPLE] CalcPress...lulesh.cc} {2038}]
#    ├─ 61821.000 [SAMPLE] CalcPress...lulesh.cc} {2042}]
#    ├─ 1000.000 [SAMPLE] CalcSound...lulesh.cc} {2187}]
#    ├─ 6998.000 [SAMPLE] CalcSound...lulesh.cc} {2190}]
#    ├─ 4999.000 [SAMPLE] CalcSound...lulesh.cc} {2191}]
#    ├─ 3000.000 [SAMPLE] CalcSound...lulesh.cc} {2192}]
#    ├─ 3002.000 [SAMPLE] CalcVeloc...lulesh.cc} {1194}]
#    ├─ 1001.000 [SAMPLE] CalcVeloc...lulesh.cc} {1195}]
#    ├─ 1001.000 [SAMPLE] CalcVeloc...lulesh.cc} {1199}]
#    ├─ 2002.000 [SAMPLE] CalcVeloc...lulesh.cc} {1202}]
#    ├─ 1001.000 [SAMPLE] CalcVeloc...lulesh.cc} {1203}]
#    ├─ 3000.000 [SAMPLE] CalcVolum...lulesh.cc} {1084}]
#    ├─ 4001.000 [SAMPLE] CollectDo.../lulesh.cc} {238}]
#    ├─ 8001.000 [SAMPLE] CollectDo.../lulesh.cc} {242}]
#    ├─ 7003.000 [SAMPLE] CollectDo.../lulesh.cc} {243}]
#    ├─ 20004.000 [SAMPLE] CollectDo.../lulesh.cc} {244}]
#    ├─ 23006.000 [SAMPLE] CollectDo.../lulesh.cc} {245}]
#    ├─ 6003.000 [SAMPLE] CollectDo.../lulesh.cc} {246}]
#    ├─ 3013.000 [SAMPLE] CollectDo.../lulesh.cc} {247}]
#    ├─ 4003.000 [SAMPLE] CollectDo.../lulesh.cc} {248}]
#    ├─ 9003.000 [SAMPLE] CollectDo.../lulesh.cc} {249}]
#    ├─ 13006.000 [SAMPLE] CollectDo.../lulesh.cc} {251}]
#    ├─ 5001.000 [SAMPLE] CollectDo.../lulesh.cc} {252}]
#    ├─ 41028.000 [SAMPLE] CollectDo.../lulesh.cc} {253}]
#    ├─ 13018.000 [SAMPLE] CollectDo.../lulesh.cc} {254}]
#    ├─ 1001.000 [SAMPLE] CollectDo.../lulesh.cc} {255}]
#    ├─ 24012.000 [SAMPLE] CollectDo.../lulesh.cc} {256}]
#    ├─ 2002.000 [SAMPLE] CollectDo.../lulesh.cc} {257}]
#    ├─ 9017.000 [SAMPLE] CollectDo.../lulesh.cc} {258}]
#    ├─ 26006.000 [SAMPLE] CollectDo.../lulesh.cc} {260}]
#    ├─ 44014.000 [SAMPLE] CollectDo.../lulesh.cc} {261}]
#    ├─ 4004.000 [SAMPLE] CollectDo.../lulesh.cc} {262}]
#    ├─ 1001.000 [SAMPLE] CollectDo.../lulesh.cc} {263}]
#    ├─ 17012.000 [SAMPLE] CollectDo.../lulesh.cc} {265}]
#    ├─ 23010.000 [SAMPLE] CollectDo.../lulesh.cc} {266}]
#    ├─ 20004.000 [SAMPLE] CollectDo.../lulesh.cc} {267}]
#    ├─ 12001.000 [SAMPLE] Domain::e...H/lulesh.h} {336}]
#    ├─ 2001.000 [SAMPLE] Domain::n...H/lulesh.h} {372}]
#    ├─ 2001.000 [SAMPLE] Domain::n...H/lulesh.h} {369}]
#    ├─ 11006.000 [SAMPLE] Domain::x...H/lulesh.h} {265}]
#    ├─ 2998.000 [SAMPLE] Domain::x...H/lulesh.h} {270}]
#    ├─ 2999.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2240}]
#    ├─ 156572.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2245}]
#    ├─ 18790.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2246}]
#    ├─ 148004.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2247}]
#    ├─ 48746.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2248}]
#    ├─ 196939.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2249}]
#    ├─ 105757.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2250}]
#    ├─ 129795.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2257}]
#    ├─ 42878.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2258}]
#    ├─ 97847.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2259}]
#    ├─ 18007.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2267}]
#    ├─ 6999.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2268}]
#    ├─ 17997.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2276}]
#    ├─ 49964.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2286}]
#    ├─ 10001.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2300}]
#    ├─ 9998.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2301}]
#    ├─ 21998.000 [SAMPLE] EvalEOSFo...lulesh.cc} {2302}]
#    ├─ 64991.000 [SAMPLE] FABS(doub...SH/lulesh.h} {52}]
#    ├─ 21009.000 [SAMPLE] InitStres.../lulesh.cc} {284}]
#    ├─ 11004.000 [SAMPLE] Integrate.../lulesh.cc} {543}]
#    ├─ 34013.000 [SAMPLE] Integrate.../lulesh.cc} {573}]
#    ├─ 8003.000 [SAMPLE] Integrate.../lulesh.cc} {575}]
#    ├─ 38029.000 [SAMPLE] Integrate.../lulesh.cc} {576}]
#    ├─ 36015.000 [SAMPLE] Integrate.../lulesh.cc} {577}]
#    ├─ 1001.000 [SAMPLE] Integrate.../lulesh.cc} {579}]
#    ├─ 73016.000 [SAMPLE] SQRT(doub...SH/lulesh.h} {44}]
#    ├─ 23011.000 [SAMPLE] SumElemFa.../lulesh.cc} {391}]
#    ├─ 11004.000 [SAMPLE] SumElemFa.../lulesh.cc} {392}]
#    ├─ 12005.000 [SAMPLE] SumElemFa.../lulesh.cc} {393}]
#    ├─ 7005.000 [SAMPLE] SumElemFa.../lulesh.cc} {394}]
#    ├─ 13005.000 [SAMPLE] SumElemFa.../lulesh.cc} {395}]
#    ├─ 15006.000 [SAMPLE] SumElemFa.../lulesh.cc} {396}]
#    ├─ 6003.000 [SAMPLE] SumElemFa.../lulesh.cc} {397}]
#    ├─ 40009.000 [SAMPLE] SumElemFa.../lulesh.cc} {398}]
#    ├─ 16010.000 [SAMPLE] SumElemFa.../lulesh.cc} {399}]
#    ├─ 9004.000 [SAMPLE] SumElemFa.../lulesh.cc} {401}]
#    ├─ 11005.000 [SAMPLE] SumElemFa.../lulesh.cc} {402}]
#    ├─ 25010.000 [SAMPLE] SumElemFa.../lulesh.cc} {403}]
#    ├─ 4003.000 [SAMPLE] SumElemFa.../lulesh.cc} {404}]
#    ├─ 5003.000 [SAMPLE] SumElemFa.../lulesh.cc} {406}]
#    ├─ 3001.000 [SAMPLE] SumElemFa.../lulesh.cc} {407}]
#    ├─ 7005.000 [SAMPLE] SumElemFa.../lulesh.cc} {408}]
#    ├─ 8008.000 [SAMPLE] SumElemFa.../lulesh.cc} {409}]
#    ├─ 5003.000 [SAMPLE] SumElemFa.../lulesh.cc} {411}]
#    ├─ 5003.000 [SAMPLE] SumElemFa.../lulesh.cc} {412}]
#    ├─ 6004.000 [SAMPLE] SumElemFa.../lulesh.cc} {413}]
#    ├─ 4003.000 [SAMPLE] SumElemFa.../lulesh.cc} {414}]
#    ├─ 4002.000 [SAMPLE] SumElemSt.../lulesh.cc} {485}]
#    ├─ 24824.000 [SAMPLE] SumElemSt.../lulesh.cc} {486}]
#    ├─ 1001.000 [SAMPLE] SumElemSt.../lulesh.cc} {487}]
#    ├─ 5996.000 [SAMPLE] SumElemSt.../lulesh.cc} {488}]
#    ├─ 1000.000 [SAMPLE] TauIntern...TauCppAPI.h} {65}]
#    ├─ 2999.000 [SAMPLE] Tau_globa...auCAPI.cpp} {344}]
#    ├─ 1000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {347}]
#    ├─ 9000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {309}]
#    ├─ 1000.000 [SAMPLE] Tau_memor...Memory.cpp} {968}]
#    ├─ 18000.000 [SAMPLE] Tau_memor...Memory.cpp} {957}]
#    ├─ 21997.000 [SAMPLE] Tau_stack...auCAPI.cpp} {236}]
#    ├─ 2000.000 [SAMPLE] UNRESOLVE...SH/build/lulesh2.0
#    ├─ 6999.000 [SAMPLE] UNRESOLVE...-ompt-v5-openmp.so
#    ├─ 11000.000 [SAMPLE] UNRESOLVE...openmp/libiomp5.so
#    ├─ 5000.000 [SAMPLE] UpdateVol...lulesh.cc} {2419}]
#    ├─ 2000.000 [SAMPLE] UpdateVol...lulesh.cc} {2420}]
#    ├─ 67030.000 [SAMPLE] VoluDer [.../lulesh.cc} {603}]
#    ├─ 21014.000 [SAMPLE] VoluDer [.../lulesh.cc} {604}]
#    ├─ 41022.000 [SAMPLE] VoluDer [.../lulesh.cc} {605}]
#    ├─ 33019.000 [SAMPLE] VoluDer [.../lulesh.cc} {607}]
#    ├─ 20012.000 [SAMPLE] VoluDer [.../lulesh.cc} {608}]
#    ├─ 36034.000 [SAMPLE] VoluDer [.../lulesh.cc} {609}]
#    ├─ 34012.000 [SAMPLE] VoluDer [.../lulesh.cc} {612}]
#    ├─ 11010.000 [SAMPLE] VoluDer [.../lulesh.cc} {613}]
#    ├─ 28009.000 [SAMPLE] VoluDer [.../lulesh.cc} {614}]
#    ├─ 14007.000 [SAMPLE] VoluDer [.../lulesh.cc} {616}]
#    ├─ 5003.000 [SAMPLE] VoluDer [.../lulesh.cc} {617}]
#    ├─ 9003.000 [SAMPLE] VoluDer [.../lulesh.cc} {618}]
#    ├─ 62974.000 [SAMPLE] __cbrt [{} {0}]
#    ├─ 1000.000 [SAMPLE] __frexp [{} {0}]
#    ├─ 101647.000 [SAMPLE] __kmp_GOM...gsupport.cpp} {0}]
#    ├─ 53856.000 [SAMPLE] __kmp_acq.../libiomp5.so} {0}]
#    ├─ 1000.000 [SAMPLE] __kmp_api..._10_alias [{} {0}]
#    ├─ 37999.000 [SAMPLE] __kmp_api..._parallel [{} {0}]
#    ├─ 16001.000 [SAMPLE] __kmp_api..._10_alias [{} {0}]
#    ├─ 16992.000 [SAMPLE] __kmp_api..._10_alias [{} {0}]
#    ├─ 5000.000 [SAMPLE] __kmp_api...hread_num [{} {0}]
#    ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
#    ├─ 1001.000 [SAMPLE] __kmp_fin...icit_task [{} {0}]
#    ├─ 28861.000 [SAMPLE] __kmp_get...thread_id [{} {0}]
#    ├─ 26905.000 [SAMPLE] __kmp_get...ad_id_reg [{} {0}]
#    ├─ 19996.000 [SAMPLE] __kmp_internal_join [{} {0}]
#    ├─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 9997.000 [SAMPLE] __kmpc_ba.../libiomp5.so} {0}]
#    ├─ 44999.000 [SAMPLE] __kmpc_bo.../libiomp5.so} {0}]
#    ├─ 4999.000 [SAMPLE] __ldexp [{} {0}]
#    ├─ 42750.000 [SAMPLE] __ompt_ge...**, int*) [{} {0}]
#    ├─ 35914.000 [SAMPLE] __ompt_ge...ject(int) [{} {0}]
#    ├─ 1998.000 [SAMPLE] __scalbn [{} {0}]
#    ├─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
#    ├─ 2001.000 [SAMPLE] double co...algobase.h} {225}]
#    ├─ 3003.000 [SAMPLE] double co...algobase.h} {226}]
#    ├─ 1000.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {663}]
#    ├─ 14000.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {678}]
#    ├─ 16002.000 [SAMPLE] std::vect...l_vector.h} {798}]
#    └─ 18002.000 [SAMPLE] std::vect...l_vector.h} {798}]
# 30566.000 OpenMP_Parallel_Re...esh.cc} {1157, 0}]
# └─ 3002.000 [CONTEXT] OpenMP_P...esh.cc} {1157, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    └─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
# 496073.000 OpenMP_Parallel_Re...esh.cc} {2500, 0}]
# └─ 28999.000 [CONTEXT] OpenMP_P...esh.cc} {2500, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    └─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
# 512027.000 OpenMP_Parallel_Re...esh.cc} {2075, 0}]
# └─ 98926.000 [CONTEXT] OpenMP_P...esh.cc} {2075, 0}]
#    ├─ 9000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {309}]
#    ├─ 18000.000 [SAMPLE] Tau_memor...Memory.cpp} {957}]
#    ├─ 53856.000 [SAMPLE] __kmp_acq.../libiomp5.so} {0}]
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
# 573039.000 OpenMP_Parallel_Re...esh.cc} {2100, 0}]
# └─ 121943.000 [CONTEXT] OpenMP_P...esh.cc} {2100, 0}]
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    ├─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
#    └─ 4999.000 [SAMPLE] __ompt_ge...nt, int*) [{} {0}]
# 521000.000 OpenMP_Parallel_Re...esh.cc} {2116, 0}]
# └─ 86988.000 [CONTEXT] OpenMP_P...esh.cc} {2116, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 10000.000 [SAMPLE] __kmp_ini...icit_task [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    ├─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
#    ├─ 35914.000 [SAMPLE] __ompt_ge...ject(int) [{} {0}]
#    └─ 4999.000 [SAMPLE] __ompt_ge...nt, int*) [{} {0}]
# 522381.000 OpenMP_Parallel_Re...esh.cc} {2153, 0}]
# └─ 98911.000 [CONTEXT] OpenMP_P...esh.cc} {2153, 0}]
#    ├─ 53856.000 [SAMPLE] __kmp_acq.../libiomp5.so} {0}]
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 9007.000 [SAMPLE] __kmp_pop...om_thread [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
# 287890.000 OpenMP_Parallel_Re...esh.cc} {1043, 0}]
# └─ 7000.000 [CONTEXT] OpenMP_P...esh.cc} {1043, 0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    └─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
# 18078.000 OpenMP_Parallel_Re...lesh.cc} {999, 0}]
# └─ 1000.000 [CONTEXT] OpenMP_P...lesh.cc} {999, 0}]
#    └─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
# 503774.000 OpenMP_Parallel_Re...esh.cc} {2560, 0}]
# └─ 37998.000 [CONTEXT] OpenMP_P...esh.cc} {2560, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 28861.000 [SAMPLE] __kmp_get...thread_id [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
# 218787.000 OpenMP_Parallel_Re...esh.cc} {1936, 0}]
# └─ 7353.000 [CONTEXT] OpenMP_P...esh.cc} {1936, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    └─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
# 30673.000 OpenMP_Parallel_Re...esh.cc} {1212, 0}]
# └─ 2999.000 [CONTEXT] OpenMP_P...esh.cc} {1212, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    └─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
# 1634266.000 OpenMP_Parallel_Re...esh.cc} {2022, 0}]
# └─ 344418.000 [CONTEXT] OpenMP_P...esh.cc} {2022, 0}]
#    ├─ 2999.000 [SAMPLE] Tau_globa...auCAPI.cpp} {344}]
#    ├─ 9000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {309}]
#    ├─ 3999.000 [SAMPLE] Tau_memor...Memory.cpp} {960}]
#    ├─ 21997.000 [SAMPLE] Tau_stack...auCAPI.cpp} {236}]
#    ├─ 11000.000 [SAMPLE] UNRESOLVE...openmp/libiomp5.so
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
# 1619691.000 OpenMP_Parallel_Re...esh.cc} {2029, 0}]
# └─ 275701.000 [CONTEXT] OpenMP_P...esh.cc} {2029, 0}]
#    ├─ 6999.000 [SAMPLE] UNRESOLVE...-ompt-v5-openmp.so
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 2999.000 [SAMPLE] __kmp_free_team [{} {0}]
#    ├─ 10000.000 [SAMPLE] __kmp_ini...icit_task [{} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    ├─ 4000.000 [SAMPLE] __kmp_sto...trol_word [{} {0}]
#    ├─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
#    └─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
# 184724.000 OpenMP_Parallel_Re...esh.cc} {2187, 0}]
# └─ 23996.000 [CONTEXT] OpenMP_P...esh.cc} {2187, 0}]
#    ├─ 6999.000 [SAMPLE] UNRESOLVE...-ompt-v5-openmp.so
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
# 16315.000 OpenMP_Parallel_Re...esh.cc} {2583, 0}]
# └─ 14999.000 [CONTEXT] OpenMP_P...esh.cc} {2583, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    └─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
# 15001.000 OpenMP_Parallel_Re...esh.cc} {1188, 0}]
# └─ 1999.000 [CONTEXT] OpenMP_P...esh.cc} {1188, 0}]
#    └─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
# 32948.000 OpenMP_Parallel_Re...esh.cc} {1064, 0}]
# └─ 10010.000 [CONTEXT] OpenMP_P...esh.cc} {1064, 0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    ├─ 989.000 [SAMPLE] __mmap64 [{} {0}]
#    └─ 32725.000 [SAMPLE] _int_malloc [{malloc.c} {0}]
# 35503.000 OpenMP_Parallel_Re...esh.cc} {1077, 0}]
# └─ 6000.000 [CONTEXT] OpenMP_P...esh.cc} {1077, 0}]
#    └─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
# 1598879.000 OpenMP_Parallel_Re...esh.cc} {2289, 0}]
# └─ 129725.000 [CONTEXT] OpenMP_P...esh.cc} {2289, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 28861.000 [SAMPLE] __kmp_get...thread_id [{} {0}]
#    ├─ 10000.000 [SAMPLE] __kmp_ini...icit_task [{} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 9007.000 [SAMPLE] __kmp_pop...om_thread [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    └─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
# 26907.000 OpenMP_Parallel_Re...esh.cc} {1261, 0}]
# └─ 2002.000 [CONTEXT] OpenMP_P...esh.cc} {1261, 0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    └─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
# 898298.000 OpenMP_Parallel_Re...ulesh.h} {118, 0}]
# └─ 98785.000 [CONTEXT] OpenMP_P...ulesh.h} {118, 0}]
#    ├─ 53856.000 [SAMPLE] __kmp_acq.../libiomp5.so} {0}]
#    ├─ 39997.000 [SAMPLE] __kmp_allocate_team [{} {0}]
#    ├─ 756379.000 [SAMPLE] __kmp_for...int, int) [{} {0}]
#    ├─ 182913.000 [SAMPLE] __kmp_for.../libiomp5.so} {0}]
#    ├─ 51996.000 [SAMPLE] __kmp_internal_fork [{} {0}]
#    ├─ 77901.000 [SAMPLE] __kmp_join_call [{} {0}]
#    ├─ 215627.000 [SAMPLE] __kmp_rel...cket_lock [{} {0}]
#    ├─ 90851.000 [SAMPLE] __kmp_task_team_setup [{} {0}]
#    ├─ 4999.000 [SAMPLE] __ompt_ge...nt, int*) [{} {0}]
#    ├─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
#    └─ 6000.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {223}]
# 11539.000 OpenMP_Sync_Region...esh.cc} {1157, 0}]
# ├─ 24754.000 [CONTEXT] OpenMP_S...esh.cc} {1157, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 24754.000 [CONTEXT] OpenMP_S...esh.cc} {1157, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 3981.000 OpenMP_Sync_Region...esh.cc} {2387, 0}]
# ├─ 1934.000 [CONTEXT] OpenMP_S...esh.cc} {2387, 0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 1934.000 [CONTEXT] OpenMP_S...esh.cc} {2387, 0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 23606.000 OpenMP_Sync_Region...esh.cc} {2347, 0}]
# ├─ 16254.000 [CONTEXT] OpenMP_S...esh.cc} {2347, 0}]
# │  ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# └─ 16254.000 [CONTEXT] OpenMP_S...esh.cc} {2347, 0}]
#    ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# 15662.000 OpenMP_Sync_Region...esh.cc} {2500, 0}]
# ├─ 14998.000 [CONTEXT] OpenMP_S...esh.cc} {2500, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 14998.000 [CONTEXT] OpenMP_S...esh.cc} {2500, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 225720.000 OpenMP_Sync_Region...esh.cc} {2496, 0}]
# ├─ 395977.000 [CONTEXT] OpenMP_S...esh.cc} {2496, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# └─ 395977.000 [CONTEXT] OpenMP_S...esh.cc} {2496, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# 79157.000 OpenMP_Sync_Region...esh.cc} {2075, 0}]
# ├─ 140990.000 [CONTEXT] OpenMP_S...esh.cc} {2075, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 140990.000 [CONTEXT] OpenMP_S...esh.cc} {2075, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 127331.000 OpenMP_Sync_Region...esh.cc} {2100, 0}]
# ├─ 299504.000 [CONTEXT] OpenMP_S...esh.cc} {2100, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 299504.000 [CONTEXT] OpenMP_S...esh.cc} {2100, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 81100.000 OpenMP_Sync_Region...esh.cc} {2116, 0}]
# ├─ 79889.000 [CONTEXT] OpenMP_S...esh.cc} {2116, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 79889.000 [CONTEXT] OpenMP_S...esh.cc} {2116, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 79833.000 OpenMP_Sync_Region...esh.cc} {2153, 0}]
# ├─ 103744.000 [CONTEXT] OpenMP_S...esh.cc} {2153, 0}]
# │  ├─ 1000.000 [SAMPLE] Tau_memor...Memory.cpp} {971}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 103744.000 [CONTEXT] OpenMP_S...esh.cc} {2153, 0}]
#    ├─ 1000.000 [SAMPLE] Tau_memor...Memory.cpp} {971}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 111737.000 OpenMP_Sync_Region...lesh.cc} {967, 0}]
# ├─ 120933.000 [CONTEXT] OpenMP_S...lesh.cc} {967, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 120933.000 [CONTEXT] OpenMP_S...lesh.cc} {967, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 24423.000 OpenMP_Sync_Region...esh.cc} {1043, 0}]
# ├─ 42004.000 [CONTEXT] OpenMP_S...esh.cc} {1043, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 42004.000 [CONTEXT] OpenMP_S...esh.cc} {1043, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 2878.000 OpenMP_Sync_Region...lesh.cc} {999, 0}]
# ├─ 7003.000 [CONTEXT] OpenMP_S...lesh.cc} {999, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 7003.000 [CONTEXT] OpenMP_S...lesh.cc} {999, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 15021.000 OpenMP_Sync_Region...esh.cc} {2560, 0}]
# ├─ 10000.000 [CONTEXT] OpenMP_S...esh.cc} {2560, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 10000.000 [CONTEXT] OpenMP_S...esh.cc} {2560, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 247060.000 OpenMP_Sync_Region...esh.cc} {2556, 0}]
# ├─ 438158.000 [CONTEXT] OpenMP_S...esh.cc} {2556, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# └─ 438158.000 [CONTEXT] OpenMP_S...esh.cc} {2556, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# 31610.000 OpenMP_Sync_Region...esh.cc} {1510, 0}]
# ├─ 27017.000 [CONTEXT] OpenMP_S...esh.cc} {1510, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 27017.000 [CONTEXT] OpenMP_S...esh.cc} {1510, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 69896.000 OpenMP_Sync_Region...esh.cc} {1936, 0}]
# ├─ 74352.000 [CONTEXT] OpenMP_S...esh.cc} {1936, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 74352.000 [CONTEXT] OpenMP_S...esh.cc} {1936, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 14342.000 OpenMP_Sync_Region...esh.cc} {1212, 0}]
# ├─ 18015.000 [CONTEXT] OpenMP_S...esh.cc} {1212, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 18015.000 [CONTEXT] OpenMP_S...esh.cc} {1212, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 291080.000 OpenMP_Sync_Region...esh.cc} {2022, 0}]
# ├─ 459841.000 [CONTEXT] OpenMP_S...esh.cc} {2022, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  ├─ 19996.000 [SAMPLE] __kmp_internal_join [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 459841.000 [CONTEXT] OpenMP_S...esh.cc} {2022, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    ├─ 19996.000 [SAMPLE] __kmp_internal_join [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 300433.000 OpenMP_Sync_Region...esh.cc} {2029, 0}]
# ├─ 470802.000 [CONTEXT] OpenMP_S...esh.cc} {2029, 0}]
# │  ├─ 3999.000 [SAMPLE] Tau_memor...Memory.cpp} {960}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  ├─ 19996.000 [SAMPLE] __kmp_internal_join [{} {0}]
# │  ├─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# │  ├─ 5000.000 [SAMPLE] __kmp_task_team_wait [{} {0}]
# │  └─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
# └─ 470802.000 [CONTEXT] OpenMP_S...esh.cc} {2029, 0}]
#    ├─ 3999.000 [SAMPLE] Tau_memor...Memory.cpp} {960}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    ├─ 19996.000 [SAMPLE] __kmp_internal_join [{} {0}]
#    ├─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
#    ├─ 5000.000 [SAMPLE] __kmp_task_team_wait [{} {0}]
#    └─ 21961.000 [SAMPLE] __tls_get...4/ld-2.17.so} {0}]
# 21257.000 OpenMP_Sync_Region...esh.cc} {1977, 0}]
# ├─ 16128.000 [CONTEXT] OpenMP_S...esh.cc} {1977, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 16128.000 [CONTEXT] OpenMP_S...esh.cc} {1977, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 43115.000 OpenMP_Sync_Region...esh.cc} {2187, 0}]
# ├─ 53755.000 [CONTEXT] OpenMP_S...esh.cc} {2187, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 53755.000 [CONTEXT] OpenMP_S...esh.cc} {2187, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 3121.000 OpenMP_Sync_Region...esh.cc} {2583, 0}]
# ├─ 1000.000 [CONTEXT] OpenMP_S...esh.cc} {2583, 0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 1000.000 [CONTEXT] OpenMP_S...esh.cc} {2583, 0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 6781.000 OpenMP_Sync_Region...esh.cc} {1064, 0}]
# ├─ 16003.000 [CONTEXT] OpenMP_S...esh.cc} {1064, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 16003.000 [CONTEXT] OpenMP_S...esh.cc} {1064, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 13271.000 OpenMP_Sync_Region...esh.cc} {1077, 0}]
# ├─ 31025.000 [CONTEXT] OpenMP_S...esh.cc} {1077, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 31025.000 [CONTEXT] OpenMP_S...esh.cc} {1077, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 69327.000 OpenMP_Sync_Region...esh.cc} {2289, 0}]
# ├─ 71000.000 [CONTEXT] OpenMP_S...esh.cc} {2289, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 71000.000 [CONTEXT] OpenMP_S...esh.cc} {2289, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 503149.000 OpenMP_Sync_Region...esh.cc} {2263, 0}]
# ├─ 598132.000 [CONTEXT] OpenMP_S...esh.cc} {2263, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  ├─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
# │  └─ 999.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {771}]
# └─ 598132.000 [CONTEXT] OpenMP_S...esh.cc} {2263, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 872236.000 [SAMPLE] __kmp_barrier [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    ├─ 129546.000 [SAMPLE] __kmp_hyp..._barrier.cpp} {0}]
#    └─ 999.000 [SAMPLE] on_ompt_c...auOMPT.cpp} {771}]
# 16092.000 OpenMP_Sync_Region...lesh.cc} {562, 0}]
# ├─ 43004.000 [CONTEXT] OpenMP_S...lesh.cc} {562, 0}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 43004.000 [CONTEXT] OpenMP_S...lesh.cc} {562, 0}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 12655.000 OpenMP_Sync_Region...esh.cc} {1261, 0}]
# ├─ 8998.000 [CONTEXT] OpenMP_S...esh.cc} {1261, 0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 8998.000 [CONTEXT] OpenMP_S...esh.cc} {1261, 0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# 183726.000 OpenMP_Sync_Region...ulesh.h} {118, 0}]
# ├─ 266608.000 [CONTEXT] OpenMP_S...ulesh.h} {118, 0}]
# │  ├─ 9000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {309}]
# │  ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
# │  └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
# └─ 266608.000 [CONTEXT] OpenMP_S...ulesh.h} {118, 0}]
#    ├─ 9000.000 [SAMPLE] Tau_globa...auCAPI.cpp} {309}]
#    ├─ 91250.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    ├─ 1227608.000 [SAMPLE] __kmp_har...timestamp [{} {0}]
#    └─ 1541796.000 [SAMPLE] __kmp_joi...rier(int) [{} {0}]
#
# Legend (Metric: inclusive_time)
# █ 11262312.00 - 12513680.00
# █ 8759576.00 - 11262312.00
# █ 6256840.00 - 8759576.00
# █ 3754104.00 - 6256840.00
# █ 1251368.00 - 3754104.00
# █ 0.00 - 1251368.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
gf.dataframe
# Out:
#                                                                                                  name  \
# node
# {'name': '.TAU application'}                                                         .TAU application
# {'name': '[CONTEXT] .TAU application'}                                     [CONTEXT] .TAU application
# {'name': '[SAMPLE] CalcElemVolume [{/home/nchai...  [SAMPLE] CalcElemVolume [{/home/nchaimov/LULES...
# {'name': '[SAMPLE] CalcEnergyForElems [{/home/n...  [SAMPLE] CalcEnergyForElems [{/home/nchaimov/L...
# {'name': '[SAMPLE] CalcMonotonicQForElems [{/ho...  [SAMPLE] CalcMonotonicQForElems [{/home/nchaim...
# ...                                                                                               ...
# {'name': '[CONTEXT] OpenMP_Sync_Region_Barrier ...  [CONTEXT] OpenMP_Sync_Region_Barrier void Rele...
# {'name': '[SAMPLE] Tau_global_incr_insideTAU [{...  [SAMPLE] Tau_global_incr_insideTAU [{/home/nch...
# {'name': '[SAMPLE] __GI___sched_yield [{} {0}]'}                 [SAMPLE] __GI___sched_yield [{} {0}]
# {'name': '[SAMPLE] __kmp_hardware_timestamp [{}...         [SAMPLE] __kmp_hardware_timestamp [{} {0}]
# {'name': '[SAMPLE] __kmp_join_barrier(int) [{} ...          [SAMPLE] __kmp_join_barrier(int) [{} {0}]
#
#                                                     exclusive_time  \
# node
# {'name': '.TAU application'}                               1396259
# {'name': '[CONTEXT] .TAU application'}                           0
# {'name': '[SAMPLE] CalcElemVolume [{/home/nchai...            8003
# {'name': '[SAMPLE] CalcEnergyForElems [{/home/n...            2000
# {'name': '[SAMPLE] CalcMonotonicQForElems [{/ho...            1005
# ...                                                            ...
# {'name': '[CONTEXT] OpenMP_Sync_Region_Barrier ...               0
# {'name': '[SAMPLE] Tau_global_incr_insideTAU [{...            9000
# {'name': '[SAMPLE] __GI___sched_yield [{} {0}]'}             91250
# {'name': '[SAMPLE] __kmp_hardware_timestamp [{}...         1227608
# {'name': '[SAMPLE] __kmp_join_barrier(int) [{} ...         1541796
#
#                                                     inclusive_time
# node
# {'name': '.TAU application'}                              12513680
# {'name': '[CONTEXT] .TAU application'}                     1211132
# {'name': '[SAMPLE] CalcElemVolume [{/home/nchai...            8003
# {'name': '[SAMPLE] CalcEnergyForElems [{/home/n...            2000
# {'name': '[SAMPLE] CalcMonotonicQForElems [{/ho...            1005
# ...                                                            ...
# {'name': '[CONTEXT] OpenMP_Sync_Region_Barrier ...          266608
# {'name': '[SAMPLE] Tau_global_incr_insideTAU [{...            9000
# {'name': '[SAMPLE] __GI___sched_yield [{} {0}]'}             91250
# {'name': '[SAMPLE] __kmp_hardware_timestamp [{}...         1227608
# {'name': '[SAMPLE] __kmp_join_barrier(int) [{} ...         1541796
#
# [944 rows x 3 columns]
